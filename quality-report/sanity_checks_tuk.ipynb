# %% [markdown]
# # MultiplEYE preprocessing

# %%
from pathlib import Path
import polars as pl
import re
from sanity import Sanity
from report import check_gaze, check_metadata, check_events, report_to_file as report_meta
from functools import partial
from plot import plot_gaze, plot_main_sequence
from stimulus import load_stimuli, Stimulus


import pymovements as pm

# %%
### Turkisch Data

path_asc_file = "data\\001_TR_TR_1_ET1\\001trtr1.asc"
stimulus_file_path = "C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\stimuli_MultiplEYE_TR_TR_Istanbul_1_2025"
logfile_path = f"C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\\001_TR_TR_1_ET1\logfiles\EXPERIMENT_LOGFILE_1_001_2025-01-16_1737022316.txt"

# %%
### Cuis test data


path_asc_file= "data\\010_ZH_CH_1_ET1\\010zhch1.asc"
stimulus_file_path = "C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\stimuli_MultiplEYE_ZH_CH_Zurich_1_2025"
logfile_path = f"C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\\010_ZH_CH_1_ET1\logfiles\EXPERIMENT_LOGFILE_1_010_2024-11-15_1731682963.txt"

# %%
### Dutch Data
path_asc_file = "data\\017_NL_NL_1_ET1_testrun_1733144369\\017nlnl1.asc"
stimulus_file_path = "C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\stimuli_MultiplEYE_NL_NL_Nijmegen_1_2024"
logfile_path = f"C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\\017_NL_NL_1_ET1_testrun_1733144369\logfiles\EXPERIMENT_LOGFILE_1_017_2024-12-02_1733144369.txt"

# %%
### Estonian Data


path_asc_file_003 = "data\\003_ET_EE_1_ET1\\003etee1.asc"
logfile_path_003 = f"C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\\003_ET_EE_1_ET1\logfiles\EXPERIMENT_LOGFILE_1_003_2025-01-17_1737097063.txt"

path_asc_file_002 = "data\\002_ET_EE_1_ET1\\002etee1.asc"
logfile_path_002 = f"C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\\002_ET_EE_1_ET1\logfiles\EXPERIMENT_LOGFILE_1_002_2025-01-16_1737035642.txt"


path_asc_file_001 = "data\\001_ET_EE_1_ET1\\001etee1.asc"
logfile_path_001 = f"C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\\001_ET_EE_1_ET1\logfiles\EXPERIMENT_LOGFILE_1_001_2025-01-16_1737028666.txt"


stimulus_file_path = "C:\\Users\saphi\PycharmProjects\multipleye-preprocessing\data\stimuli_MultiplEYE_ET_EE_Tartu_1_2025"

# %%
local_file_part = "C:\\Users\saphi\PycharmProjects\multipleye-preprocessing"

sanity = Sanity.load(path_asc_file_001, local_file_part, stimulus_file_path, logfile_path_001)
sanity002 = Sanity.load(path_asc_file_002, local_file_part, stimulus_file_path, logfile_path_002)
sanity003 = Sanity.load(path_asc_file_003, local_file_part, stimulus_file_path, logfile_path_003)
# Out:
# Match was found at 5-33: 001_ET_EE_1_ET1\001etee1.asc
# Group 1 found at 5-8: 001
# Group 2 found at 9-11: ET
# Group 3 found at 12-14: EE
# Group 4 found at 15-16: 1
# Group 5 found at 17-20: ET1
# Group 6 found at -1--1: None
# Group 7 found at 21-29: 001etee1
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing
# 96
# Match was found at 5-33: 002_ET_EE_1_ET1\002etee1.asc
# Group 1 found at 5-8: 002
# Group 2 found at 9-11: ET
# Group 3 found at 12-14: EE
# Group 4 found at 15-16: 1
# Group 5 found at 17-20: ET1
# Group 6 found at -1--1: None
# Group 7 found at 21-29: 002etee1
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing
# 96
# Match was found at 5-33: 003_ET_EE_1_ET1\003etee1.asc
# Group 1 found at 5-8: 003
# Group 2 found at 9-11: ET
# Group 3 found at 12-14: EE
# Group 4 found at 15-16: 1
# Group 5 found at 17-20: ET1
# Group 6 found at -1--1: None
# Group 7 found at 21-29: 003etee1
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing
# 96

# %%
sanity.asc_file
# Out:
# WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/001_ET_EE_1_ET1/001etee1.asc')

# %%
sanity.completed_stimuli
# Out:
# shape: (12, 6)
# ┌───────────────────┬───────────────────┬────────────┬─────────────┬───────────────────┬───────────┐
# │ timestamp_started ┆ timestamp_complet ┆ trial_id   ┆ stimulus_id ┆ stimulus_name     ┆ completed │
# │ ---               ┆ ed                ┆ ---        ┆ ---         ┆ ---               ┆ ---       │
# │ f64               ┆ ---               ┆ str        ┆ i64         ┆ str               ┆ i64       │
# │                   ┆ f64               ┆            ┆             ┆                   ┆           │
# ╞═══════════════════╪═══════════════════╪════════════╪═════════════╪═══════════════════╪═══════════╡
# │ 913183.8043       ┆ 1.0137e6          ┆ PRACTICE_1 ┆ 13          ┆ Enc_WikiMoon      ┆ 1         │
# │ 1.0137e6          ┆ 1.0628e6          ┆ PRACTICE_2 ┆ 7           ┆ Lit_NorthWind     ┆ 1         │
# │ 1.1297e6          ┆ 1.3428e6          ┆ 1          ┆ 12          ┆ PopSci_Caveman    ┆ 1         │
# │ 1.3724e6          ┆ 1.7979e6          ┆ 2          ┆ 8           ┆ Lit_Solaris       ┆ 1         │
# │ 1.8538e6          ┆ 2.1273e6          ┆ 3          ┆ 9           ┆ Lit_BrokenApril   ┆ 1         │
# │ …                 ┆ …                 ┆ …          ┆ …           ┆ …                 ┆ …         │
# │ 3.2737e6          ┆ 3.4368e6          ┆ 6          ┆ 4           ┆ Lit_Alchemist     ┆ 1         │
# │ 3.4595e6          ┆ 3.7749e6          ┆ 7          ┆ 11          ┆ Arg_PISARapaNui   ┆ 1         │
# │ 3.8365e6          ┆ 4.0545e6          ┆ 8          ┆ 6           ┆ Lit_MagicMountain ┆ 1         │
# │ 4.1107e6          ┆ 4.4682e6          ┆ 9          ┆ 1           ┆ PopSci_MultiplEYE ┆ 1         │
# │ 4.5208e6          ┆ 4.7343e6          ┆ 10         ┆ 2           ┆ Ins_HumanRights   ┆ 1         │
# └───────────────────┴───────────────────┴────────────┴─────────────┴───────────────────┴───────────┘

# %%
stimulus_name = "PopSci_MultiplEYE"

stimulus = Stimulus.load(sanity002.stimulus_file_path, sanity.lang, sanity.country, sanity.labnum, stimulus_name)
print(stimulus)
# Out:
# Stimulus(id=1, name='PopSci_MultiplEYE', type='experiment', pages=[StimulusPage(number=1, text='MultiplEYE projekt\n\nNimi „MultiplEYE“ on sõnamäng, mis ühendab sõnad „multilingualism“ (mitmekeelsus) või „multiple languages“ (mitu keelt) ja „eye“ (silm) sõnast „eye-tracking“ (silmaseire). MultiplEYE on COST aktsioon, mida rahastab Euroopa Liit. COST aktsioonid on teadusvõrgustikud, mida toetab „European Cooperation in Science and Technology“ (Euroopa teaduse ja tehnoloogia koostöövõrgustik) ehk lühidalt COST. COST toetab kasvavat teadlaste võrgustikku üle Euroopa ja kaugemal, pakkudes rahalist toetust erinevate koostöö tegevuste läbiviimiseks. ', image_path=WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/stimuli_MultiplEYE_ET_EE_Tartu_1_2025/stimuli_images_ET_EE_1/popsci_multipleye_id1_page_1_ET.png')), StimulusPage(number=2, text='Nende tegevuste hulka kuuluvad töögruppide kohtumised, koolitused oskuste jagamiseks noorte teadlastega ja teadustöö külastused. MultiplEYE COST aktsiooni pealkiri on inglise keelest tõlgituna - Mitmekeelse silmaseire andmekogu võimaldamine inimese ja masina keele töötluse uuringuteks. See tähendab, et MultiplEYE COST aktsioon soovib edendada interdistsiplinaarsete uurimisgruppide võrgustikku, kes tegeleb lugemise silmaseire andmete kogumisega erinevates keeltes. ', image_path=WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/stimuli_MultiplEYE_ET_EE_Tartu_1_2025/stimuli_images_ET_EE_1/popsci_multipleye_id1_page_2_ET.png')), StimulusPage(number=3, text='Eesmärk on toetada suure mitmekeelse silmaseire korpuse arendamist ja võimaldada uurijatel andmete kogumist, jagades oma teadmisi erinevatest valdkondadest, sealhulgas keeleteadusest, psühholoogiast, kõne- ja keelepatoloogiast ning arvutiteadusest. Seda andmekogu on seejärel võimalik kasutada nii inimese keeletöötluse uurimiseks psühholingvistilisest vaatenurgast kui ka selleks, et hinnata arvuti keeletöötlust masinõppe vaatenurgast.', image_path=WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/stimuli_MultiplEYE_ET_EE_Tartu_1_2025/stimuli_images_ET_EE_1/popsci_multipleye_id1_page_3_ET.png')), StimulusPage(number=4, text='Mis on  „silmaseire“?\nSilmaseire on protsess, kus mõõdetakse pilgupunkti - kuhu Sa vaatad - ja silmade liikumist kindlate pilgupunktide vahel. Silmade asukoha ja liikumise mõõtmiseks kasutatavat seadet nimetatakse pilgujälgijaks (eye-tracker). See koosneb infrapunakaamerast, mis kasutab valgussagedust, mis ei häiri ega tee inimsilmale haiget.', image_path=WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/stimuli_MultiplEYE_ET_EE_Tartu_1_2025/stimuli_images_ET_EE_1/popsci_multipleye_id1_page_4_ET.png')), StimulusPage(number=5, text='Kujutise tuvastamist võimaldavate algortmide abil suudab pilgujälgija arvutada pilgu asukoha välja väga täpselt, teades pea ja silmade asukoha koordinaate, vahemaad ekraanist, mida osaleja vaatab ja pilgujälgija asukohta. \nSilmaseire on kasulik tehnoloogia mitmete rakendusviiside jaoks. Näiteks võib see aidata tuvastada väsimust autojuhtimisel või hõlbustada skriinimist ja väljaõpet meditsiinivaldkonnas. Silmaseiret kasutatakse ka arvutimängudes, turunduses ja inimese-arvuti suhtluses.', image_path=WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/stimuli_MultiplEYE_ET_EE_Tartu_1_2025/stimuli_images_ET_EE_1/popsci_multipleye_id1_page_5_ET.png')), StimulusPage(number=6, text='Miks on silmaseire lugemise ajal eriti huvitav meie projekti jaoks?\nSamal ajal kui Sa neid sõnu loed, mõõdab pilgujälgija Sinu pilgu liikumist üle teksti. See annab meile infot, kui kaua Sa veedad aega teksti vaatamisel, ehk täpsemalt, kui kaua Sa veetsid igal sõnal, millised sõnad vahele jätsid, millistel sõnadel pikemalt peatusid, ja kas Sa pidid tagasi minema, ja mõnda tekstiosa üle lugema, et sellest paremini aru saada.', image_path=WindowsPath('C:/Users/saphi/PycharmProjects/multipleye-preprocessing/data/s ...

# %%
import importlib
stimulus_config_spec = importlib.util.spec_from_file_location(
        "stimulus_config", sanity.experiment_config
    )

stimulus_config = importlib.util.module_from_spec(stimulus_config_spec)
stimulus_config_spec.loader.exec_module(stimulus_config)

stimulus_config.IMAGE_WIDTH_PX
# Out:
# 1584

# %%
gaze = sanity002.get_frame()
print(gaze)
# Out:
# Experiment(sampling_rate=1000.00, screen=Screen(width_px=1585, height_px=1199, width_cm=37, height_cm=28, distance_cm=60.00, origin=upper left), eyetracker=EyeTracker(sampling_rate=1000.0, left=False, right=True, model='EyeLink 1000 Plus', version='5.12', vendor='EyeLink', mount='Desktop'))
# shape: (4_013_952, 10)
# ┌──────────┬───────┬────────────┬────────────┬───┬──────────┬────────────┬────────────┬────────────┐
# │ time     ┆ pupil ┆ screen     ┆ trial      ┆ … ┆ practice ┆ pixel      ┆ position   ┆ velocity   │
# │ ---      ┆ ---   ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---        ┆ ---        ┆ ---        │
# │ i64      ┆ f64   ┆ str        ┆ str        ┆   ┆ bool     ┆ list[f64]  ┆ list[f64]  ┆ list[f64]  │
# ╞══════════╪═══════╪════════════╪════════════╪═══╪══════════╪════════════╪════════════╪════════════╡
# │ 9545335  ┆ 851.0 ┆ page_1     ┆ PRACTICE_t ┆ … ┆ true     ┆ [78.2,     ┆ [-15.52071 ┆ [0.094587, │
# │          ┆       ┆            ┆ rial_1     ┆   ┆          ┆ 102.4]     ┆ 8, -10.939 ┆ 1.520853]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 422]       ┆            │
# │ 9545336  ┆ 851.0 ┆ page_1     ┆ PRACTICE_t ┆ … ┆ true     ┆ [78.1,     ┆ [-15.52278 ┆ [0.11519,  │
# │          ┆       ┆            ┆ rial_1     ┆   ┆          ┆ 102.5]     ┆ 7, -10.937 ┆ 1.596166]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 272]       ┆            │
# │ 9545337  ┆ 850.0 ┆ page_1     ┆ PRACTICE_t ┆ … ┆ true     ┆ [78.1,     ┆ [-15.52278 ┆ [0.139539, │
# │          ┆       ┆            ┆ rial_1     ┆   ┆          ┆ 102.5]     ┆ 7, -10.937 ┆ 1.664864]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 272]       ┆            │
# │ 9545338  ┆ 850.0 ┆ page_1     ┆ PRACTICE_t ┆ … ┆ true     ┆ [78.2,     ┆ [-15.52071 ┆ [0.162764, │
# │          ┆       ┆            ┆ rial_1     ┆   ┆          ┆ 102.6]     ┆ 8, -10.935 ┆ 1.736677]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 122]       ┆            │
# │ 9545339  ┆ 850.0 ┆ page_1     ┆ PRACTICE_t ┆ … ┆ true     ┆ [78.3,     ┆ [-15.51864 ┆ [0.180183, │
# │          ┆       ┆            ┆ rial_1     ┆   ┆          ┆ 102.7]     ┆ 8, -10.932 ┆ 1.811218]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 972]       ┆            │
# │ …        ┆ …     ┆ …          ┆ …          ┆ … ┆ …        ┆ …          ┆ …          ┆ …          │
# │ 14851154 ┆ 757.0 ┆ question_3 ┆ trial_10   ┆ … ┆ false    ┆ [1513.0,   ┆ [15.669618 ┆ [1.832308, │
# │          ┆       ┆ 131        ┆            ┆   ┆          ┆ 1107.1]    ┆ ,          ┆ 0.04021]   │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 11.186431] ┆            │
# │ 14851155 ┆ 758.0 ┆ question_3 ┆ trial_10   ┆ … ┆ false    ┆ [1512.8,   ┆ [15.665485 ┆ [1.755226, │
# │          ┆       ┆ 131        ┆            ┆   ┆          ┆ 1107.1]    ┆ ,          ┆ 0.057302]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 11.186431] ┆            │
# │ 14851156 ┆ 758.0 ┆ question_3 ┆ trial_10   ┆ … ┆ false    ┆ [1512.5,   ┆ [15.659285 ┆ [1.656996, │
# │          ┆       ┆ 131        ┆            ┆   ┆          ┆ 1107.2]    ┆ ,          ┆ 0.089152]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 11.188578] ┆            │
# │ 14851157 ┆ 758.0 ┆ question_3 ┆ trial_10   ┆ … ┆ false    ┆ [1512.3,   ┆ [15.655151 ┆ [1.537056, │
# │          ┆       ┆ 131        ┆            ┆   ┆          ┆ 1107.7]    ┆ ,          ┆ 0.131293]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 11.199307] ┆            │
# │ 14851158 ┆ 755.0 ┆ question_3 ┆ trial_10   ┆ … ┆ false    ┆ [1512.6,   ┆ [15.661351 ┆ [1.394843, │
# │          ┆       ┆ 131        ┆            ┆   ┆          ┆ 1108.1]    ┆ ,          ┆ 0.174017]  │
# │          ┆       ┆            ┆            ┆   ┆          ┆            ┆ 11.207891] ┆            │
# └──────────┴───────┴────────────┴────────────┴───┴──────────┴────────────┴────────────┴────────────┘

# %%
gaze.frame.filter(pl.col("activity") == "question").unique("screen")
# Out:
# shape: (64, 10)
# ┌─────────┬────────┬─────────────┬──────────┬───┬──────────┬─────────────┬────────────┬────────────┐
# │ time    ┆ pupil  ┆ screen      ┆ trial    ┆ … ┆ practice ┆ pixel       ┆ position   ┆ velocity   │
# │ ---     ┆ ---    ┆ ---         ┆ ---      ┆   ┆ ---      ┆ ---         ┆ ---        ┆ ---        │
# │ i64     ┆ f64    ┆ str         ┆ str      ┆   ┆ bool     ┆ list[f64]   ┆ list[f64]  ┆ list[f64]  │
# ╞═════════╪════════╪═════════════╪══════════╪═══╪══════════╪═════════════╪════════════╪════════════╡
# │ 2142740 ┆ 1053.0 ┆ question_91 ┆ trial_3  ┆ … ┆ false    ┆ [315.3,     ┆ [-10.50708 ┆ [-2.999474 │
# │         ┆        ┆ 32          ┆          ┆   ┆          ┆ 313.9]      ┆ 1,         ┆ , -24.0230 │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -6.331905] ┆ 12]        │
# │ 2662225 ┆ 1043.0 ┆ question_10 ┆ trial_4  ┆ … ┆ false    ┆ [404.2,     ┆ [-8.580018 ┆ [-3.125521 │
# │         ┆        ┆ 222         ┆          ┆   ┆          ┆ 299.5]      ┆ ,          ┆ , -11.8640 │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -6.648925] ┆ 19]        │
# │ 2719154 ┆ 1015.0 ┆ question_10 ┆ trial_4  ┆ … ┆ false    ┆ [478.7,     ┆ [-6.949716 ┆ [-0.462322 │
# │         ┆        ┆ 232         ┆          ┆   ┆          ┆ 313.6]      ┆ ,          ┆ ,          │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -6.338513] ┆ -1.181465] │
# │ 4043930 ┆ 1007.0 ┆ question_61 ┆ trial_8  ┆ … ┆ false    ┆ [363.7,     ┆ [-9.460622 ┆ [-0.658268 │
# │         ┆        ┆ 21          ┆          ┆   ┆          ┆ 172.5]      ┆ ,          ┆ ,          │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -9.425122] ┆ -0.05086]  │
# │ 3736380 ┆ 989.0  ┆ question_11 ┆ trial_7  ┆ … ┆ false    ┆ [448.1,     ┆ [-7.620865 ┆ [2.591653, │
# │         ┆        ┆ 212         ┆          ┆   ┆          ┆ 246.2]      ┆ ,          ┆ -7.478887] │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -7.818641] ┆            │
# │ …       ┆ …      ┆ …           ┆ …        ┆ … ┆ …        ┆ …           ┆ …          ┆ …          │
# │ 1332297 ┆ 1042.0 ┆ question_12 ┆ trial_1  ┆ … ┆ false    ┆ [339.0,     ┆ [-9.995503 ┆ [-1.208405 │
# │         ┆        ┆ 112         ┆          ┆   ┆          ┆ 327.5]      ┆ ,          ┆ , 0.39379] │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -6.032139] ┆            │
# │ 4433928 ┆ 1073.0 ┆ question_11 ┆ trial_9  ┆ … ┆ false    ┆ [319.4,     ┆ [-10.41869 ┆ [-1.394573 │
# │         ┆        ┆ 22          ┆          ┆   ┆          ┆ 565.8]      ┆ 9,         ┆ ,          │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -0.740328] ┆ 0.046006]  │
# │ 3750332 ┆ 870.0  ┆ question_11 ┆ trial_7  ┆ … ┆ false    ┆ [408.6,     ┆ [-8.484094 ┆ [2.100796, │
# │         ┆        ┆ 121         ┆          ┆   ┆          ┆ 342.3]      ┆ ,          ┆ -1.95196]  │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -5.705546] ┆            │
# │ 4688614 ┆ 1123.0 ┆ question_21 ┆ trial_10 ┆ … ┆ false    ┆ [354.8,     ┆ [-9.653549 ┆ [0.704316, │
# │         ┆        ┆ 11          ┆          ┆   ┆          ┆ 237.6]      ┆ ,          ┆ 1.06143]   │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆ -8.006789] ┆            │
# │ 1367480 ┆ 1100.0 ┆ question_12 ┆ trial_1  ┆ … ┆ false    ┆ [979.3,     ┆ [4.167875, ┆ [-0.419827 │
# │         ┆        ┆ 132         ┆          ┆   ┆          ┆ 562.2]      ┆ -0.820594] ┆ ,          │
# │         ┆        ┆             ┆          ┆   ┆          ┆             ┆            ┆ -1.829223] │
# └─────────┴────────┴─────────────┴──────────┴───┴──────────┴─────────────┴────────────┴────────────┘

# %%
gaze.frame.filter(pl.col("stimulus") == "PopSci_Caveman_12").filter(pl.col("activity") == "rating").unique(pl.col("screen"))
# Out:
# shape: (3, 10)
# ┌─────────┬────────┬─────────────┬─────────┬───┬──────────┬─────────────┬─────────────┬────────────┐
# │ time    ┆ pupil  ┆ screen      ┆ trial   ┆ … ┆ practice ┆ pixel       ┆ position    ┆ velocity   │
# │ ---     ┆ ---    ┆ ---         ┆ ---     ┆   ┆ ---      ┆ ---         ┆ ---         ┆ ---        │
# │ i64     ┆ f64    ┆ str         ┆ str     ┆   ┆ bool     ┆ list[f64]   ┆ list[f64]   ┆ list[f64]  │
# ╞═════════╪════════╪═════════════╪═════════╪═══╪══════════╪═════════════╪═════════════╪════════════╡
# │ 1325847 ┆ 1039.0 ┆ subject_dif ┆ trial_1 ┆ … ┆ false    ┆ [380.9,     ┆ [-9.087163, ┆ [3.994145, │
# │         ┆        ┆ ficulty_scr ┆         ┆   ┆          ┆ 250.6]      ┆ -7.722314]  ┆ -1.655743] │
# │         ┆        ┆ een         ┆         ┆   ┆          ┆             ┆             ┆            │
# │ 1322071 ┆ 1017.0 ┆ familiarity ┆ trial_1 ┆ … ┆ false    ┆ [182.0,     ┆ [-13.350951 ┆ [-0.068559 │
# │         ┆        ┆ _rating_scr ┆         ┆   ┆          ┆ 452.4]      ┆ ,           ┆ ,          │
# │         ┆        ┆ een_2       ┆         ┆   ┆          ┆             ┆ -3.265679]  ┆ -0.007643] │
# │ 1319751 ┆ 838.0  ┆ familiarity ┆ trial_1 ┆ … ┆ false    ┆ [1496.6,    ┆ [15.330143, ┆ [-0.372294 │
# │         ┆        ┆ _rating_scr ┆         ┆   ┆          ┆ 1119.1]     ┆ 11.443733]  ┆ ,          │
# │         ┆        ┆ een_1       ┆         ┆   ┆          ┆             ┆             ┆ -0.545593] │
# └─────────┴────────┴─────────────┴─────────┴───┴──────────┴─────────────┴─────────────┴────────────┘

# %%
### inspect Metadata
gaze._metadata
# Out:
# {'weekday': 'Thu',
#  'month': 'Jan',
#  'day': 16,
#  'time': '15:34:29',
#  'year': 2025,
#  'version_1': 'EYELINK II 1',
#  'version_2': 'EYELINK II CL v5.12 May 12 2017',
#  'resolution': (1585, 1199),
#  'tracking_mode': 'CR',
#  'sampling_rate': 1000.0,
#  'file_sample_filter': '2',
#  'link_sample_filter': '1',
#  'tracked_eye': 'R',
#  'mount_configuration': {'mount_type': 'Desktop',
#   'head_stabilization': 'stabilized',
#   'eyes_recorded': 'monocular',
#   'short_name': 'MTABLER'},
#  'pupil_data_type': 'AREA',
#  'version_number': '5.12',
#  'model': 'EyeLink 1000 Plus',
#  'datetime': datetime.datetime(2025, 1, 16, 15, 34, 29),
#  'calibrations': [{'timestamp': '9129603.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9201781.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9448289.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9481210.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9915402.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '10363669.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '10928705.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '11471625.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '11862009.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '12576792.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '13261434.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '14206068.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '14452185.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'}],
#  'validations': [{'timestamp': '9299961.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'FAIR ERROR',
#    'validation_score_avg': '0.49',
#    'validation_score_max': '1.94'},
#   {'timestamp': '9497011.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.23',
#    'validation_score_max': '0.47'},
#   {'timestamp': '9900225.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.27',
#    'validation_score_max': '0.53'},
#   {'timestamp': '9930932.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.19',
#    'validation_score_max': '0.66'},
#   {'timestamp': '10374779.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.39'},
#   {'timestamp': '10943067.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.18',
#    'validation_score_max': '0.44'},
#   {'timestamp': '11456253.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.50'},
#   {'timestamp': '11488536.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.30',
#    'validation_score_max': '0.59'},
#   {'timestamp': '11875001.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.13',
#    'validation_score_max': '0.60'},
#   {'timestamp': '12593643.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.20',
#    'validation_score_max': '0.39'},
#   {'timestamp': '12980746.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.30',
#    'validation_score_max': '0.69'},
#   {'timestamp': '13275653.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.16',
#    'validation_score_max': '0.51'},
#   {'timestamp': '14219957.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.23',
#    'validation_score_max': '0.98'},
#   {'timestamp': '14434447.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.85'},
#   {'timestamp': '14470997.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.29',
#    'validation_score_max': '1.37'},
#   {'timestamp': '14873568.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.42',
#    'validation_score_max': '1.14'}],
#  'blinks': [{'start_timestamp': 9545980.0,
#    'stop_timestamp': 9546041.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 9548344.0,
#    'stop_timestamp': 9548435.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 9556683.0,
#    'stop_timestamp': 9556705.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 9560517.0,
#    'stop_timestamp': 9560683.0,
#    'duration_ms': 167.0,
#    'num_samples': 0},
#   {'start_timestamp': 9562284.0,
#    'stop_timestamp': 9562381.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 9572180.0,
#    'stop_timestamp': 9572258.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 9577177.0,
#    'stop_timestamp': 9577237.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 9580868.0,
#    'stop_timestamp': 9580965.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 9583209.0,
#    'stop_timestamp': 9583290.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 9588451.0,
#    'stop_timestamp': 9588505.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 9593662.0,
#    'stop_timestamp': 9593745.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 9598803.0,
#    'stop_timestamp': 9598878.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 9604662.0,
#    'stop_timestamp': 9604740.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 9610928.0,
#    'stop_timestamp': 9611027.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 9617980.0,
#    'stop_timestamp': 9618054.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 9625564.0,
#    'stop_timestamp': 9625658.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 9629991.0,
#    'stop_timestamp': 9630087.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 9632873.0,
#    'stop_timestamp': 9632979.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 9643868.0,
#    'stop_timestamp': 9643915.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 9644251.0,
#    'stop_timestamp': 9644421.0,
#    'duration_ms': 171.0,
#    'num_samples': 0},
#   {'start_timestamp': 9648928.0,
#    'stop_timestamp': 9649001.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 9654145.0,
#    'stop_timestamp': 9654229.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 9655968.0,
#    'stop_timestamp': 9656055.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 9666238.0,
#    'stop_timestamp': 9666321.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 9673892.0,
#    'stop_timestamp': 9673978.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 9679237.0,
#    'stop_timestamp': 9679342.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 9691195.0,
#    'stop_timestamp': 9691213.0,
#    'duration_ms': 19.0,
#    'num_samples': 0},
#   {'start_timestamp': 9692917.0,
#    'stop_timestamp': 9692999.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 9694862.0,
#    'stop_timestamp': 9694958.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 9704707.0,
#    'stop_timestamp': 9704775.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 9706742.0,
#    'stop_timestamp': 9706829.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 9724936.0,
#    'stop_timestamp': 9725014.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 9737581.0,
#    'stop_timestamp': 9737705.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 9746267.0,
#    'stop_timestamp': 9746286.0,
#    'duration_ms': 20.0,
#    'num_samples': 0},
#   {'start_timestamp': 9747540.0,
#    'stop_timestamp': 9747671.0,
#    'duration_ms': 132.0,
#    'num_samples': 0},
#   {'start_timestamp': 9752178.0,
#    'stop_timestamp': 9752192.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 9757077.0,
#    'stop_timestamp': 9757107.0,
#    'duration_ms': 31.0,
#    'num_samples': 0},
#   {'start_timestamp': 9762755.0,
#    'stop_timestamp': 9762803.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 9769558.0,
#    'stop_timestamp': 9769616.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 9771784.0,
#    'stop_timestamp': 9771823.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 9772248.0,
#    'stop_timestamp': 9772376.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 9776761.0,
#    'stop_timestamp': 9776850.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 9781515.0,
#    'stop_timestamp': 9781603.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 9795673.0,
#    'stop_timestamp': 9795737.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 9815204.0,
#    'stop_timestamp': 9815289.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 9827416.0,
#    'stop_timestamp': 9827488.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 9945834.0,
#    'stop_timestamp': 9945834.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 9958905.0,
#    'stop_timestamp': 9958930.0,
#    'duration_ms': 26.0,
#    'num_samples': 0},
#   {'start_timestamp': 9970452.0,
#    'stop_timestamp': 9970508.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 9974353.0,
#    'stop_timestamp': 9974425.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 9988058.0,
#    'stop_timestamp': 9988128.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 9994104.0,
#    'stop_timestamp': 9994172.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10011175.0,
#    'stop_timestamp': 10011229.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 10017041.0,
#    'stop_timestamp': 10017133.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10032229.0,
#    'stop_timestamp': 10032386.0,
#    'duration_ms': 158.0,
#    'num_samples': 0},
#   {'start_timestamp': 10035072.0,
#    'stop_timestamp': 10035121.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 10040696.0,
#    'stop_timestamp': 10040737.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 10046008.0,
#    'stop_timestamp': 10046102.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 10052676.0,
#    'stop_timestamp': 10052754.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 10060573.0,
#    'stop_timestamp': 10060661.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 10075821.0,
#    'stop_timestamp': 10075866.0,
#    'duration_ms': 46.0,
#    'num_samples': 0},
#   {'start_timestamp': 10077753.0,
#    'stop_timestamp': 10077835.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 10078941.0,
#    'stop_timestamp': 10079069.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 10082699.0,
#    'stop_timestamp': 10082779.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 10090468.0,
#    'stop_timestamp': 10090536.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10091414.0,
#    'stop_timestamp': 10091533.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 10096482.0,
#    'stop_timestamp': 10096577.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10103345.0,
#    'stop_timestamp': 10103429.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10109577.0,
#    'stop_timestamp': 10109666.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10118282.0,
#    'stop_timestamp': 10118371.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10121437.0,
#    'stop_timestamp': 10121514.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 10125059.0,
#    'stop_timestamp': 10125137.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 10128785.0,
#    'stop_timestamp': 10128852.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 10131548.0,
#    'stop_timestamp': 10131643.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10137852.0,
#    'stop_timestamp': 10137967.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10150083.0,
#    'stop_timestamp': 10150145.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 10152010.0,
#    'stop_timestamp': 10152109.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 10158513.0,
#    'stop_timestamp': 10158646.0,
#    'duration_ms': 134.0,
#    'num_samples': 0},
#   {'start_timestamp': 10165372.0,
#    'stop_timestamp': 10165438.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10169472.0,
#    'stop_timestamp': 10169542.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 10199234.0,
#    'stop_timestamp': 10199320.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 10212082.0,
#    'stop_timestamp': 10212172.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10230139.0,
#    'stop_timestamp': 10230180.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 10237392.0,
#    'stop_timestamp': 10237397.0,
#    'duration_ms': 6.0,
#    'num_samples': 0},
#   {'start_timestamp': 10240868.0,
#    'stop_timestamp': 10240970.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10252208.0,
#    'stop_timestamp': 10252277.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 10259699.0,
#    'stop_timestamp': 10259741.0,
#    'duration_ms': 43.0,
#    'num_samples': 0},
#   {'start_timestamp': 10273010.0,
#    'stop_timestamp': 10273087.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 10280844.0,
#    'stop_timestamp': 10280946.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10284227.0,
#    'stop_timestamp': 10284276.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 10286724.0,
#    'stop_timestamp': 10286800.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 10290632.0,
#    'stop_timestamp': 10290707.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 10291947.0,
#    'stop_timestamp': 10292044.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10295194.0,
#    'stop_timestamp': 10295360.0,
#    'duration_ms': 167.0,
#    'num_samples': 0},
#   {'start_timestamp': 10297592.0,
#    'stop_timestamp': 10297714.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 10299511.0,
#    'stop_timestamp': 10299597.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 10303469.0,
#    'stop_timestamp': 10303573.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 10305769.0,
#    'stop_timestamp': 10305864.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10312248.0,
#    'stop_timestamp': 10312331.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 10318430.0,
#    'stop_timestamp': 10318528.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 10319714.0,
#    'stop_timestamp': 10319856.0,
#    'duration_ms': 143.0,
#    'num_samples': 0},
#   {'start_timestamp': 10333333.0,
#    'stop_timestamp': 10333430.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10382514.0,
#    'stop_timestamp': 10382603.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10385769.0,
#    'stop_timestamp': 10385861.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10388923.0,
#    'stop_timestamp': 10388983.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 10404001.0,
#    'stop_timestamp': 10404056.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 10414837.0,
#    'stop_timestamp': 10414901.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 10426749.0,
#    'stop_timestamp': 10426831.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 10430197.0,
#    'stop_timestamp': 10430255.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 10434700.0,
#    'stop_timestamp': 10434768.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10436025.0,
#    'stop_timestamp': 10436126.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 10439187.0,
#    'stop_timestamp': 10439239.0,
#    'duration_ms': 53.0,
#    'num_samples': 0},
#   {'start_timestamp': 10441788.0,
#    'stop_timestamp': 10441890.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10448296.0,
#    'stop_timestamp': 10448417.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 10452434.0,
#    'stop_timestamp': 10452519.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 10455000.0,
#    'stop_timestamp': 10455088.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 10457753.0,
#    'stop_timestamp': 10457836.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 10467846.0,
#    'stop_timestamp': 10467964.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 10474806.0,
#    'stop_timestamp': 10474873.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 10479362.0,
#    'stop_timestamp': 10479451.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10487318.0,
#    'stop_timestamp': 10487375.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 10504747.0,
#    'stop_timestamp': 10504787.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 10510076.0,
#    'stop_timestamp': 10510157.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 10512697.0,
#    'stop_timestamp': 10512711.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 10519905.0,
#    'stop_timestamp': 10519919.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 10521409.0,
#    'stop_timestamp': 10521513.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 10533102.0,
#    'stop_timestamp': 10533181.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10542170.0,
#    'stop_timestamp': 10542263.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 10548933.0,
#    'stop_timestamp': 10548988.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 10556728.0,
#    'stop_timestamp': 10556775.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 10567461.0,
#    'stop_timestamp': 10567534.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 10569374.0,
#    'stop_timestamp': 10569459.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 10571035.0,
#    'stop_timestamp': 10571114.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10572579.0,
#    'stop_timestamp': 10572645.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10580007.0,
#    'stop_timestamp': 10580072.0,
#    'duration_ms': 66.0,
#    'num_samples': 0},
#   {'start_timestamp': 10585831.0,
#    'stop_timestamp': 10585902.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 10593431.0,
#    'stop_timestamp': 10593574.0,
#    'duration_ms': 144.0,
#    'num_samples': 0},
#   {'start_timestamp': 10596068.0,
#    'stop_timestamp': 10596159.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 10598859.0,
#    'stop_timestamp': 10598955.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 10612081.0,
#    'stop_timestamp': 10612173.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10620750.0,
#    'stop_timestamp': 10620895.0,
#    'duration_ms': 146.0,
#    'num_samples': 0},
#   {'start_timestamp': 10622132.0,
#    'stop_timestamp': 10622193.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 10625807.0,
#    'stop_timestamp': 10625866.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 10626171.0,
#    'stop_timestamp': 10626273.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10626488.0,
#    'stop_timestamp': 10626587.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 10626876.0,
#    'stop_timestamp': 10626973.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10627166.0,
#    'stop_timestamp': 10627281.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10627492.0,
#    'stop_timestamp': 10627601.0,
#    'duration_ms': 110.0,
#    'num_samples': 0},
#   {'start_timestamp': 10629593.0,
#    'stop_timestamp': 10629666.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 10634448.0,
#    'stop_timestamp': 10634561.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 10640807.0,
#    'stop_timestamp': 10640874.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 10643398.0,
#    'stop_timestamp': 10643533.0,
#    'duration_ms': 136.0,
#    'num_samples': 0},
#   {'start_timestamp': 10653029.0,
#    'stop_timestamp': 10653144.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10661129.0,
#    'stop_timestamp': 10661213.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10665603.0,
#    'stop_timestamp': 10665669.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10669566.0,
#    'stop_timestamp': 10669651.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 10681442.0,
#    'stop_timestamp': 10681532.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10691049.0,
#    'stop_timestamp': 10691130.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 10693162.0,
#    'stop_timestamp': 10693235.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 10704765.0,
#    'stop_timestamp': 10704880.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10705602.0,
#    'stop_timestamp': 10705705.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 10706819.0,
#    'stop_timestamp': 10706915.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 10710365.0,
#    'stop_timestamp': 10710509.0,
#    'duration_ms': 145.0,
#    'num_samples': 0},
#   {'start_timestamp': 10713890.0,
#    'stop_timestamp': 10713929.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 10714117.0,
#    'stop_timestamp': 10714207.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10715026.0,
#    'stop_timestamp': 10715147.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 10719611.0,
#    'stop_timestamp': 10719677.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10724082.0,
#    'stop_timestamp': 10724161.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10726210.0,
#    'stop_timestamp': 10726318.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 10729183.0,
#    'stop_timestamp': 10729321.0,
#    'duration_ms': 139.0,
#    'num_samples': 0},
#   {'start_timestamp': 10729773.0,
#    'stop_timestamp': 10729896.0,
#    'duration_ms': 124.0,
#    'num_samples': 0},
#   {'start_timestamp': 10741754.0,
#    'stop_timestamp': 10741884.0,
#    'duration_ms': 131.0,
#    'num_samples': 0},
#   {'start_timestamp': 10751788.0,
#    'stop_timestamp': 10751878.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10755579.0,
#    'stop_timestamp': 10755658.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10758616.0,
#    'stop_timestamp': 10758722.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 10761315.0,
#    'stop_timestamp': 10761412.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10775826.0,
#    'stop_timestamp': 10775920.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 10779579.0,
#    'stop_timestamp': 10779699.0,
#    'duration_ms': 121.0,
#    'num_samples': 0},
#   {'start_timestamp': 10786494.0,
#    'stop_timestamp': 10786563.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 10791819.0,
#    'stop_timestamp': 10791885.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10795096.0,
#    'stop_timestamp': 10795164.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10796861.0,
#    'stop_timestamp': 10796989.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 10800741.0,
#    'stop_timestamp': 10800821.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 10802629.0,
#    'stop_timestamp': 10802734.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 10808932.0,
#    'stop_timestamp': 10809016.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10810174.0,
#    'stop_timestamp': 10810362.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 10818883.0,
#    'stop_timestamp': 10818993.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 10821259.0,
#    'stop_timestamp': 10821353.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 10822082.0,
#    'stop_timestamp': 10822204.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 10829890.0,
#    'stop_timestamp': 10829914.0,
#    'duration_ms': 25.0,
#    'num_samples': 0},
#   {'start_timestamp': 10830448.0,
#    'stop_timestamp': 10830549.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 10841378.0,
#    'stop_timestamp': 10841481.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 10845368.0,
#    'stop_timestamp': 10845434.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10850405.0,
#    'stop_timestamp': 10850526.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 10856873.0,
#    'stop_timestamp': 10856977.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 10858756.0,
#    'stop_timestamp': 10858892.0,
#    'duration_ms': 137.0,
#    'num_samples': 0},
#   {'start_timestamp': 10860233.0,
#    'stop_timestamp': 10860281.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 10860719.0,
#    'stop_timestamp': 10860814.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10865837.0,
#    'stop_timestamp': 10865944.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 10872763.0,
#    'stop_timestamp': 10872910.0,
#    'duration_ms': 148.0,
#    'num_samples': 0},
#   {'start_timestamp': 10874902.0,
#    'stop_timestamp': 10874988.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 10878947.0,
#    'stop_timestamp': 10879043.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 10882333.0,
#    'stop_timestamp': 10882416.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 10891271.0,
#    'stop_timestamp': 10891376.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 10951855.0,
#    'stop_timestamp': 10951855.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 10956206.0,
#    'stop_timestamp': 10956266.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 10964856.0,
#    'stop_timestamp': 10964948.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10972603.0,
#    'stop_timestamp': 10972664.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 10980229.0,
#    'stop_timestamp': 10980313.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10981965.0,
#    'stop_timestamp': 10982089.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 10983609.0,
#    'stop_timestamp': 10983717.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 10995080.0,
#    'stop_timestamp': 10995138.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 10998020.0,
#    'stop_timestamp': 10998091.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 11000523.0,
#    'stop_timestamp': 11000622.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11003931.0,
#    'stop_timestamp': 11004016.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 11008984.0,
#    'stop_timestamp': 11009002.0,
#    'duration_ms': 19.0,
#    'num_samples': 0},
#   {'start_timestamp': 11017015.0,
#    'stop_timestamp': 11017016.0,
#    'duration_ms': 2.0,
#    'num_samples': 0},
#   {'start_timestamp': 11022428.0,
#    'stop_timestamp': 11022508.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11025326.0,
#    'stop_timestamp': 11025439.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 11028046.0,
#    'stop_timestamp': 11028077.0,
#    'duration_ms': 32.0,
#    'num_samples': 0},
#   {'start_timestamp': 11040801.0,
#    'stop_timestamp': 11040883.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 11047564.0,
#    'stop_timestamp': 11047631.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 11057214.0,
#    'stop_timestamp': 11057294.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11061941.0,
#    'stop_timestamp': 11061991.0,
#    'duration_ms': 51.0,
#    'num_samples': 0},
#   {'start_timestamp': 11070537.0,
#    'stop_timestamp': 11070537.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 11073195.0,
#    'stop_timestamp': 11073288.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11085492.0,
#    'stop_timestamp': 11085583.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 11089803.0,
#    'stop_timestamp': 11089875.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 11093608.0,
#    'stop_timestamp': 11093695.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 11105020.0,
#    'stop_timestamp': 11105137.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 11109272.0,
#    'stop_timestamp': 11109286.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 11116180.0,
#    'stop_timestamp': 11116270.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 11118978.0,
#    'stop_timestamp': 11119071.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11129040.0,
#    'stop_timestamp': 11129113.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 11132317.0,
#    'stop_timestamp': 11132387.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 11141254.0,
#    'stop_timestamp': 11141329.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 11147539.0,
#    'stop_timestamp': 11147622.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 11155339.0,
#    'stop_timestamp': 11155402.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 11160666.0,
#    'stop_timestamp': 11160732.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 11163111.0,
#    'stop_timestamp': 11163191.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11165071.0,
#    'stop_timestamp': 11165148.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11178605.0,
#    'stop_timestamp': 11178693.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 11188415.0,
#    'stop_timestamp': 11188507.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 11192281.0,
#    'stop_timestamp': 11192313.0,
#    'duration_ms': 33.0,
#    'num_samples': 0},
#   {'start_timestamp': 11194063.0,
#    'stop_timestamp': 11194182.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 11200451.0,
#    'stop_timestamp': 11200513.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 11202797.0,
#    'stop_timestamp': 11202884.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 11206492.0,
#    'stop_timestamp': 11206571.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 11213162.0,
#    'stop_timestamp': 11213255.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11216234.0,
#    'stop_timestamp': 11216329.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 11228019.0,
#    'stop_timestamp': 11228111.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 11231823.0,
#    'stop_timestamp': 11231907.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 11237856.0,
#    'stop_timestamp': 11237905.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 11240406.0,
#    'stop_timestamp': 11240482.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 11256426.0,
#    'stop_timestamp': 11256550.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 11259521.0,
#    'stop_timestamp': 11259599.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 11261930.0,
#    'stop_timestamp': 11262028.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 11264450.0,
#    'stop_timestamp': 11264501.0,
#    'duration_ms': 52.0,
#    'num_samples': 0},
#   {'start_timestamp': 11269035.0,
#    'stop_timestamp': 11269150.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 11271196.0,
#    'stop_timestamp': 11271305.0,
#    'duration_ms': 110.0,
#    'num_samples': 0},
#   {'start_timestamp': 11273169.0,
#    'stop_timestamp': 11273264.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 11274363.0,
#    'stop_timestamp': 11274476.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 11281393.0,
#    'stop_timestamp': 11281482.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 11289442.0,
#    'stop_timestamp': 11289499.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 11293001.0,
#    'stop_timestamp': 11293103.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11295978.0,
#    'stop_timestamp': 11296106.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 11304523.0,
#    'stop_timestamp': 11304624.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 11310162.0,
#    'stop_timestamp': 11310239.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11313689.0,
#    'stop_timestamp': 11313813.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 11317398.0,
#    'stop_timestamp': 11317535.0,
#    'duration_ms': 138.0,
#    'num_samples': 0},
#   {'start_timestamp': 11331576.0,
#    'stop_timestamp': 11331687.0,
#    'duration_ms': 112.0,
#    'num_samples': 0},
#   {'start_timestamp': 11335225.0,
#    'stop_timestamp': 11335347.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 11340749.0,
#    'stop_timestamp': 11340787.0,
#    'duration_ms': 39.0,
#    'num_samples': 0},
#   {'start_timestamp': 11352176.0,
#    'stop_timestamp': 11352271.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 11361292.0,
#    'stop_timestamp': 11361394.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11372032.0,
#    'stop_timestamp': 11372140.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 11378804.0,
#    'stop_timestamp': 11378827.0,
#    'duration_ms': 24.0,
#    'num_samples': 0},
#   {'start_timestamp': 11388391.0,
#    'stop_timestamp': 11388490.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11394074.0,
#    'stop_timestamp': 11394133.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 11396528.0,
#    'stop_timestamp': 11396632.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11405260.0,
#    'stop_timestamp': 11405323.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 11414744.0,
#    'stop_timestamp': 11414837.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11495334.0,
#    'stop_timestamp': 11495389.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 11498959.0,
#    'stop_timestamp': 11499053.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 11502549.0,
#    'stop_timestamp': 11502626.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11507209.0,
#    'stop_timestamp': 11507291.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 11513517.0,
#    'stop_timestamp': 11513613.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 11515647.0,
#    'stop_timestamp': 11515757.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 11529407.0,
#    'stop_timestamp': 11529490.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 11536531.0,
#    'stop_timestamp': 11536592.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 11540637.0,
#    'stop_timestamp': 11540723.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 11543300.0,
#    'stop_timestamp': 11543400.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 11553846.0,
#    'stop_timestamp': 11553950.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11581891.0,
#    'stop_timestamp': 11581943.0,
#    'duration_ms': 53.0,
#    'num_samples': 0},
#   {'start_timestamp': 11583714.0,
#    'stop_timestamp': 11583822.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 11589976.0,
#    'stop_timestamp': 11589977.0,
#    'duration_ms': 2.0,
#    'num_samples': 0},
#   {'start_timestamp': 11593689.0,
#    'stop_timestamp': 11593733.0,
#    'duration_ms': 45.0,
#    'num_samples': 0},
#   {'start_timestamp': 11597711.0,
#    'stop_timestamp': 11597803.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 11599752.0,
#    'stop_timestamp': 11599801.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 11607952.0,
#    'stop_timestamp': 11608054.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11628615.0,
#    'stop_timestamp': 11628693.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 11636665.0,
#    'stop_timestamp': 11636753.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 11646127.0,
#    'stop_timestamp': 11646259.0,
#    'duration_ms': 133.0,
#    'num_samples': 0},
#   {'start_timestamp': 11653800.0,
#    'stop_timestamp': 11653836.0,
#    'duration_ms': 37.0,
#    'num_samples': 0},
#   {'start_timestamp': 11655080.0,
#    'stop_timestamp': 11655165.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 11656754.0,
#    'stop_timestamp': 11656845.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 11659368.0,
#    'stop_timestamp': 11659443.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 11663397.0,
#    'stop_timestamp': 11663532.0,
#    'duration_ms': 136.0,
#    'num_samples': 0},
#   {'start_timestamp': 11666675.0,
#    'stop_timestamp': 11666769.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 11672057.0,
#    'stop_timestamp': 11672124.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 11674487.0,
#    'stop_timestamp': 11674591.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11675811.0,
#    'stop_timestamp': 11675885.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 11683452.0,
#    'stop_timestamp': 11683567.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 11691849.0,
#    'stop_timestamp': 11691928.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 11697521.0,
#    'stop_timestamp': 11697614.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11699111.0,
#    'stop_timestamp': 11699304.0,
#    'duration_ms': 194.0,
#    'num_samples': 0},
#   {'start_timestamp': 11699743.0,
#    'stop_timestamp': 11699863.0,
#    'duration_ms': 121.0,
#    'num_samples': 0},
#   {'start_timestamp': 11703207.0,
#    'stop_timestamp': 11703303.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 11707780.0,
#    'stop_timestamp': 11707870.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 11713357.0,
#    'stop_timestamp': 11713450.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11716696.0,
#    'stop_timestamp': 11716774.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 11724846.0,
#    'stop_timestamp': 11724945.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11730484.0,
#    'stop_timestamp': 11730561.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11733949.0,
#    'stop_timestamp': 11734046.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 11739044.0,
#    'stop_timestamp': 11739162.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 11752201.0,
#    'stop_timestamp': 11752266.0,
#    'duration_ms': 66.0,
#    'num_samples': 0},
#   {'start_timestamp': 11762024.0,
#    'stop_timestamp': 11762124.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 11767394.0,
#    'stop_timestamp': 11767458.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 11770140.0,
#    'stop_timestamp': 11770239.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11781039.0,
#    'stop_timestamp': 11781142.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 11791713.0,
#    'stop_timestamp': 11791780.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 11794050.0,
#    'stop_timestamp': 11794130.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11797217.0,
#    'stop_timestamp': 11797285.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 11810129.0,
#    'stop_timestamp': 11810256.0,
#    'duration_ms': 128.0,
#    'num_samples': 0},
#   {'start_timestamp': 11814502.0,
#    'stop_timestamp': 11814554.0,
#    'duration_ms': 53.0,
#    'num_samples': 0},
#   {'start_timestamp': 11881848.0,
#    'stop_timestamp': 11881931.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 11884598.0,
#    'stop_timestamp': 11884656.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 11887878.0,
#    'stop_timestamp': 11887918.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 11894441.0,
#    'stop_timestamp': 11894515.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 11896457.0,
#    'stop_timestamp': 11896544.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 11903984.0,
#    'stop_timestamp': 11904074.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 11910286.0,
#    'stop_timestamp': 11910405.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 11917388.0,
#    'stop_timestamp': 11917531.0,
#    'duration_ms': 144.0,
#    'num_samples': 0},
#   {'start_timestamp': 11952462.0,
#    'stop_timestamp': 11952530.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 11961306.0,
#    'stop_timestamp': 11961408.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11965687.0,
#    'stop_timestamp': 11965791.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11972326.0,
#    'stop_timestamp': 11972448.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 11974588.0,
#    'stop_timestamp': 11974643.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 11978368.0,
#    'stop_timestamp': 11978444.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 11981577.0,
#    'stop_timestamp': 11981659.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 11984939.0,
#    'stop_timestamp': 11985011.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 12019475.0,
#    'stop_timestamp': 12019530.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 12035089.0,
#    'stop_timestamp': 12035132.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 12056967.0,
#    'stop_timestamp': 12057053.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 12087496.0,
#    'stop_timestamp': 12087554.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 12102294.0,
#    'stop_timestamp': 12102364.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 12110466.0,
#    'stop_timestamp': 12110524.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 12117675.0,
#    'stop_timestamp': 12117725.0,
#    'duration_ms': 51.0,
#    'num_samples': 0},
#   {'start_timestamp': 12127778.0,
#    'stop_timestamp': 12127831.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 12133665.0,
#    'stop_timestamp': 12133707.0,
#    'duration_ms': 43.0,
#    'num_samples': 0},
#   {'start_timestamp': 12138896.0,
#    'stop_timestamp': 12138975.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 12167731.0,
#    'stop_timestamp': 12167853.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 12173585.0,
#    'stop_timestamp': 12173671.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 12184458.0,
#    'stop_timestamp': 12184549.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 12190120.0,
#    'stop_timestamp': 12190236.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 12205119.0,
#    'stop_timestamp': 12205135.0,
#    'duration_ms': 17.0,
#    'num_samples': 0},
#   {'start_timestamp': 12206951.0,
#    'stop_timestamp': 12207042.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 12213997.0,
#    'stop_timestamp': 12214090.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 12221449.0,
#    'stop_timestamp': 12221547.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 12236049.0,
#    'stop_timestamp': 12236156.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 12250386.0,
#    'stop_timestamp': 12250474.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 12260590.0,
#    'stop_timestamp': 12260668.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 12268179.0,
#    'stop_timestamp': 12268287.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 12277882.0,
#    'stop_timestamp': 12277956.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 12608270.0,
#    'stop_timestamp': 12608270.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 12620496.0,
#    'stop_timestamp': 12620565.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 12653456.0,
#    'stop_timestamp': 12653575.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 12660769.0,
#    'stop_timestamp': 12660769.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 12666836.0,
#    'stop_timestamp': 12666852.0,
#    'duration_ms': 17.0,
#    'num_samples': 0},
#   {'start_timestamp': 12681522.0,
#    'stop_timestamp': 12681602.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 12697949.0,
#    'stop_timestamp': 12698039.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 12700267.0,
#    'stop_timestamp': 12700332.0,
#    'duration_ms': 66.0,
#    'num_samples': 0},
#   {'start_timestamp': 12703038.0,
#    'stop_timestamp': 12703125.0,
#    'duration_ms': 88.0,
# ...
#   {'start_timestamp': 13670003.0,
#    'stop_timestamp': 13670084.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 13674773.0,
#    'stop_timestamp': 13674893.0,
#    'duration_ms': 121.0,
#    'num_samples': 0},
#   {'start_timestamp': 13680320.0,
#    'stop_timestamp': 13680387.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 13689148.0,
#    'stop_timestamp': 13689171.0,
#    'duration_ms': 24.0,
#    'num_samples': 0},
#   {'start_timestamp': 13697204.0,
#    'stop_timestamp': 13697257.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 13699885.0,
#    'stop_timestamp': 13699948.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 13705002.0,
#    'stop_timestamp': 13705093.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 13713105.0,
#    'stop_timestamp': 13713158.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 13718797.0,
#    'stop_timestamp': 13718893.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 13720230.0,
#    'stop_timestamp': 13720333.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 13727484.0,
#    'stop_timestamp': 13727611.0,
#    'duration_ms': 128.0,
#    'num_samples': 0},
#   {'start_timestamp': 13729521.0,
#    'stop_timestamp': 13729654.0,
#    'duration_ms': 134.0,
#    'num_samples': 0},
#   {'start_timestamp': 13743709.0,
#    'stop_timestamp': 13743830.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 13750673.0,
#    'stop_timestamp': 13750787.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 13755840.0,
#    'stop_timestamp': 13755995.0,
#    'duration_ms': 156.0,
#    'num_samples': 0},
#   {'start_timestamp': 13775857.0,
#    'stop_timestamp': 13775886.0,
#    'duration_ms': 30.0,
#    'num_samples': 0},
#   {'start_timestamp': 13783524.0,
#    'stop_timestamp': 13783553.0,
#    'duration_ms': 30.0,
#    'num_samples': 0},
#   {'start_timestamp': 13786154.0,
#    'stop_timestamp': 13786195.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 13794882.0,
#    'stop_timestamp': 13794986.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 13798928.0,
#    'stop_timestamp': 13798997.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 13810767.0,
#    'stop_timestamp': 13810831.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 13816654.0,
#    'stop_timestamp': 13816790.0,
#    'duration_ms': 137.0,
#    'num_samples': 0},
#   {'start_timestamp': 13817627.0,
#    'stop_timestamp': 13818168.0,
#    'duration_ms': 542.0,
#    'num_samples': 0},
#   {'start_timestamp': 13832570.0,
#    'stop_timestamp': 13832640.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 13841148.0,
#    'stop_timestamp': 13841258.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 13847642.0,
#    'stop_timestamp': 13847704.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 13868703.0,
#    'stop_timestamp': 13868801.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 13877254.0,
#    'stop_timestamp': 13877344.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 13878578.0,
#    'stop_timestamp': 13878657.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 13881619.0,
#    'stop_timestamp': 13881736.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 13884714.0,
#    'stop_timestamp': 13884832.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 13885375.0,
#    'stop_timestamp': 13885563.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 13886279.0,
#    'stop_timestamp': 13886393.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 13888411.0,
#    'stop_timestamp': 13888528.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 13889622.0,
#    'stop_timestamp': 13889735.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 13895726.0,
#    'stop_timestamp': 13895823.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 13897674.0,
#    'stop_timestamp': 13897771.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 13902810.0,
#    'stop_timestamp': 13902893.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 13905235.0,
#    'stop_timestamp': 13905282.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 13909213.0,
#    'stop_timestamp': 13909294.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 13917603.0,
#    'stop_timestamp': 13917659.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 13920867.0,
#    'stop_timestamp': 13920943.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 13924411.0,
#    'stop_timestamp': 13924481.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 13928617.0,
#    'stop_timestamp': 13928701.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 13942466.0,
#    'stop_timestamp': 13942512.0,
#    'duration_ms': 47.0,
#    'num_samples': 0},
#   {'start_timestamp': 13943433.0,
#    'stop_timestamp': 13943528.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 13957111.0,
#    'stop_timestamp': 13957232.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 13959301.0,
#    'stop_timestamp': 13959397.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 13962637.0,
#    'stop_timestamp': 13962739.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 13966630.0,
#    'stop_timestamp': 13966780.0,
#    'duration_ms': 151.0,
#    'num_samples': 0},
#   {'start_timestamp': 13969500.0,
#    'stop_timestamp': 13969601.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 13973459.0,
#    'stop_timestamp': 13973547.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 13999147.0,
#    'stop_timestamp': 13999200.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 14001221.0,
#    'stop_timestamp': 14001243.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 14010561.0,
#    'stop_timestamp': 14010600.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 14015349.0,
#    'stop_timestamp': 14015463.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 14039422.0,
#    'stop_timestamp': 14039518.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 14044016.0,
#    'stop_timestamp': 14044108.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 14063282.0,
#    'stop_timestamp': 14063351.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 14066101.0,
#    'stop_timestamp': 14066144.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 14073385.0,
#    'stop_timestamp': 14073473.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 14074600.0,
#    'stop_timestamp': 14074676.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 14076820.0,
#    'stop_timestamp': 14077025.0,
#    'duration_ms': 206.0,
#    'num_samples': 0},
#   {'start_timestamp': 14077883.0,
#    'stop_timestamp': 14078017.0,
#    'duration_ms': 135.0,
#    'num_samples': 0},
#   {'start_timestamp': 14080316.0,
#    'stop_timestamp': 14080415.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 14091871.0,
#    'stop_timestamp': 14091992.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 14092742.0,
#    'stop_timestamp': 14093233.0,
#    'duration_ms': 492.0,
#    'num_samples': 0},
#   {'start_timestamp': 14096242.0,
#    'stop_timestamp': 14096309.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 14098971.0,
#    'stop_timestamp': 14099032.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 14106052.0,
#    'stop_timestamp': 14106130.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 14106644.0,
#    'stop_timestamp': 14106832.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 14110822.0,
#    'stop_timestamp': 14110967.0,
#    'duration_ms': 146.0,
#    'num_samples': 0},
#   {'start_timestamp': 14121700.0,
#    'stop_timestamp': 14121762.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 14141312.0,
#    'stop_timestamp': 14141413.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 14146565.0,
#    'stop_timestamp': 14146668.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 14147755.0,
#    'stop_timestamp': 14147795.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 14156661.0,
#    'stop_timestamp': 14156767.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 14160084.0,
#    'stop_timestamp': 14160198.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 14170429.0,
#    'stop_timestamp': 14170555.0,
#    'duration_ms': 127.0,
#    'num_samples': 0},
#   {'start_timestamp': 14231754.0,
#    'stop_timestamp': 14231777.0,
#    'duration_ms': 24.0,
#    'num_samples': 0},
#   {'start_timestamp': 14233837.0,
#    'stop_timestamp': 14233886.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 14242622.0,
#    'stop_timestamp': 14242636.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 14294597.0,
#    'stop_timestamp': 14294750.0,
#    'duration_ms': 154.0,
#    'num_samples': 0},
#   {'start_timestamp': 14297645.0,
#    'stop_timestamp': 14297752.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 14308354.0,
#    'stop_timestamp': 14308432.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 14314380.0,
#    'stop_timestamp': 14314457.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 14322324.0,
#    'stop_timestamp': 14322346.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 14329214.0,
#    'stop_timestamp': 14329298.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 14331445.0,
#    'stop_timestamp': 14331501.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 14336037.0,
#    'stop_timestamp': 14336114.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 14351761.0,
#    'stop_timestamp': 14351910.0,
#    'duration_ms': 150.0,
#    'num_samples': 0},
#   {'start_timestamp': 14352597.0,
#    'stop_timestamp': 14352845.0,
#    'duration_ms': 249.0,
#    'num_samples': 0},
#   {'start_timestamp': 14360063.0,
#    'stop_timestamp': 14360162.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 14361894.0,
#    'stop_timestamp': 14361970.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 14364070.0,
#    'stop_timestamp': 14364113.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 14371322.0,
#    'stop_timestamp': 14371411.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 14392267.0,
#    'stop_timestamp': 14392362.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 14415509.0,
#    'stop_timestamp': 14415602.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 14488993.0,
#    'stop_timestamp': 14489061.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 14512999.0,
#    'stop_timestamp': 14513055.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 14515836.0,
#    'stop_timestamp': 14515939.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 14532898.0,
#    'stop_timestamp': 14532965.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 14543917.0,
#    'stop_timestamp': 14544004.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 14579267.0,
#    'stop_timestamp': 14579333.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 14582083.0,
#    'stop_timestamp': 14582134.0,
#    'duration_ms': 52.0,
#    'num_samples': 0},
#   {'start_timestamp': 14588729.0,
#    'stop_timestamp': 14588816.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 14594002.0,
#    'stop_timestamp': 14594097.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 14598187.0,
#    'stop_timestamp': 14598253.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 14607065.0,
#    'stop_timestamp': 14607214.0,
#    'duration_ms': 150.0,
#    'num_samples': 0},
#   {'start_timestamp': 14620432.0,
#    'stop_timestamp': 14620508.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 14627313.0,
#    'stop_timestamp': 14627373.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 14655536.0,
#    'stop_timestamp': 14655624.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 14665776.0,
#    'stop_timestamp': 14665837.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 14667812.0,
#    'stop_timestamp': 14667902.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 14671400.0,
#    'stop_timestamp': 14671456.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 14686795.0,
#    'stop_timestamp': 14686877.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 14690322.0,
#    'stop_timestamp': 14690359.0,
#    'duration_ms': 38.0,
#    'num_samples': 0},
#   {'start_timestamp': 14702028.0,
#    'stop_timestamp': 14702162.0,
#    'duration_ms': 135.0,
#    'num_samples': 0},
#   {'start_timestamp': 14711132.0,
#    'stop_timestamp': 14711284.0,
#    'duration_ms': 153.0,
#    'num_samples': 0},
#   {'start_timestamp': 14712402.0,
#    'stop_timestamp': 14712498.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 14718910.0,
#    'stop_timestamp': 14719072.0,
#    'duration_ms': 163.0,
#    'num_samples': 0},
#   {'start_timestamp': 14725371.0,
#    'stop_timestamp': 14725443.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 14741894.0,
#    'stop_timestamp': 14741990.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 14746803.0,
#    'stop_timestamp': 14746886.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 14750167.0,
#    'stop_timestamp': 14750275.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 14766660.0,
#    'stop_timestamp': 14766733.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 14779104.0,
#    'stop_timestamp': 14779136.0,
#    'duration_ms': 33.0,
#    'num_samples': 0},
#   {'start_timestamp': 14783027.0,
#    'stop_timestamp': 14783104.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 14784623.0,
#    'stop_timestamp': 14784662.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 14788680.0,
#    'stop_timestamp': 14788801.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 14791098.0,
#    'stop_timestamp': 14791216.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 14794885.0,
#    'stop_timestamp': 14794907.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 14800068.0,
#    'stop_timestamp': 14800137.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 14805258.0,
#    'stop_timestamp': 14805396.0,
#    'duration_ms': 139.0,
#    'num_samples': 0},
#   {'start_timestamp': 14806357.0,
#    'stop_timestamp': 14806550.0,
#    'duration_ms': 194.0,
#    'num_samples': 0},
#   {'start_timestamp': 14812291.0,
#    'stop_timestamp': 14812369.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 14816159.0,
#    'stop_timestamp': 14816251.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 14825929.0,
#    'stop_timestamp': 14825983.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 14829694.0,
#    'stop_timestamp': 14829810.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 14840094.0,
#    'stop_timestamp': 14840179.0,
#    'duration_ms': 86.0,
#    'num_samples': 0}],
#  'data_loss_ratio': 4.762376463954525e-07,
#  'data_loss_ratio_blinks': 0.0,
#  'total_recording_duration_ms': 4199584.0}

# %%
for part in [sanity, sanity002, sanity003]:
    gaze = part.get_frame()
    report_file_2 = open(f"{part.report_file}", "w", encoding="utf-8")
    report = partial(report_meta, report_file=report_file_2)
    check_gaze(gaze, report)    
    check_metadata(gaze._metadata, report)
    report_file_2.close()
    report_file_2 = open(f"{sanity.report_file}", "r", encoding="utf-8")
    print(report_file_2.readlines())
# Out:
# ['✅ Number of practice trials: 2\n', '✅ Number of trials: 10\n', '❌ Number of calibrations: 14\n', '✅ AVG validation scores: 0.28, 0.14, 0.19, 0.2, 0.39, 0.16, 0.25, 0.27, 0.15, 0.15, 0.28, 0.14, 0.52, 0.15, 0.19, 0.39, 0.15, 0.34, 0.45\n', '❌ MAX validation scores: 0.82, 0.89, 0.91, 0.78, 0.94, 0.26, 0.36, 0.58, 0.35, 0.85, 0.71, 0.61, 1.06, 0.71, 0.64, 0.63, 0.41, 0.5, 0.8\n', '✅ Validation errors: GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD\n', '✅ tracked_eye: R\n', '✅ Validation tracked Eyes: R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R\n', '✅ Data loss ratio: 0.000030%\n', '✅ Data loss ratio due to blinks: 0.000000%\n', '❌ Total recording duration: 55.489016666666664\n', '✅ Sampling rate: 1000.0\n']
# ['✅ Number of practice trials: 2\n', '✅ Number of trials: 10\n', '❌ Number of calibrations: 14\n', '✅ AVG validation scores: 0.28, 0.14, 0.19, 0.2, 0.39, 0.16, 0.25, 0.27, 0.15, 0.15, 0.28, 0.14, 0.52, 0.15, 0.19, 0.39, 0.15, 0.34, 0.45\n', '❌ MAX validation scores: 0.82, 0.89, 0.91, 0.78, 0.94, 0.26, 0.36, 0.58, 0.35, 0.85, 0.71, 0.61, 1.06, 0.71, 0.64, 0.63, 0.41, 0.5, 0.8\n', '✅ Validation errors: GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD\n', '✅ tracked_eye: R\n', '✅ Validation tracked Eyes: R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R\n', '✅ Data loss ratio: 0.000030%\n', '✅ Data loss ratio due to blinks: 0.000000%\n', '❌ Total recording duration: 55.489016666666664\n', '✅ Sampling rate: 1000.0\n']
# ['✅ Number of practice trials: 2\n', '✅ Number of trials: 10\n', '❌ Number of calibrations: 14\n', '✅ AVG validation scores: 0.28, 0.14, 0.19, 0.2, 0.39, 0.16, 0.25, 0.27, 0.15, 0.15, 0.28, 0.14, 0.52, 0.15, 0.19, 0.39, 0.15, 0.34, 0.45\n', '❌ MAX validation scores: 0.82, 0.89, 0.91, 0.78, 0.94, 0.26, 0.36, 0.58, 0.35, 0.85, 0.71, 0.61, 1.06, 0.71, 0.64, 0.63, 0.41, 0.5, 0.8\n', '✅ Validation errors: GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD\n', '✅ tracked_eye: R\n', '✅ Validation tracked Eyes: R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R\n', '✅ Data loss ratio: 0.000030%\n', '✅ Data loss ratio due to blinks: 0.000000%\n', '❌ Total recording duration: 55.489016666666664\n', '✅ Sampling rate: 1000.0\n']

# %%
report_file_2 = open(f"{sanity002.report_file}", "w", encoding="utf-8")
report = partial(report_meta, report_file=report_file_2)
check_gaze(gaze, report)    
check_metadata(gaze._metadata, report)
report_file_2.close()

# %%
report_file_2 = open(f"{sanity002.report_file}", "r", encoding="utf-8")
report_file_2.readlines()
# Out:
# ['✅ Number of practice trials: 2\n',
#  '✅ Number of trials: 10\n',
#  '❌ Date: 15:34:29 16 16 2025\n',
#  '❌ Number of calibrations: 13\n',
#  '❌ Number of validations: 16\n',
#  '✅ AVG validation scores: 0.49, 0.23, 0.27, 0.19, 0.24, 0.18, 0.24, 0.3, 0.13, 0.2, 0.3, 0.16, 0.23, 0.24, 0.29, 0.42\n',
#  '❌ MAX validation scores: 1.94, 0.47, 0.53, 0.66, 0.39, 0.44, 0.5, 0.59, 0.6, 0.39, 0.69, 0.51, 0.98, 0.85, 1.37, 1.14\n',
#  '❌ Validation errors: FAIR, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD, GOOD\n',
#  '✅ tracked_eye: R\n',
#  '✅ Validation tracked Eyes: R, R, R, R, R, R, R, R, R, R, R, R, R, R, R, R\n',
#  '✅ Data loss ratio: 0.000048%\n',
#  '✅ Data loss ratio due to blinks: 0.000000%\n',
#  '❌ Total recording duration: 69.99306666666666\n',
#  '✅ Sampling rate: 1000.0\n']

# %% [markdown]
# ### preprocess gaze data to create event dataframe, which is used for plotting

# %%
f gaze.events
# Out:
#   Cell In[18], line 1
#     f gaze.events
#       ^
# SyntaxError: invalid syntax

# %%
plot_main_sequence(gaze.events, sanity.plot_dir)

# %%
check_events(gaze, report) # not implemented yet

# %%
plot_main_sequence(gaze.events, sanity.plot_dir)

# %%
print(gaze.events.frame)

# %% [markdown]
# ### Plotting

# %%
stimuli, labconfig = load_stimuli(sanity002.stimulus_file_path, sanity.lang, sanity.country, sanity.labnum)

# %%
for stimulus in stimuli:
    print(f"Plotting {stimulus.name}...")
    plot_gaze(gaze, stimulus, sanity.plot_dir)

# %% [markdown]
# ### Loading Logfile

# %%
sanity002.logfile
# Out:
# shape: (411, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬──────────┬───────────┬───────────┐
# │ timestamp ┆ trial_num ┆ stimulus_ ┆ page_numb ┆ … ┆ key_press ┆ question ┆ answer_co ┆ message   │
# │ ---       ┆ ber       ┆ number    ┆ er        ┆   ┆ ed        ┆ ---      ┆ rrect     ┆ ---       │
# │ f64       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str      ┆ ---       ┆ str       │
# │           ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆          ┆ str       ┆           │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════════╪═══════════╪═══════════╡
# │ 16228.486 ┆ <NA>      ┆ <NA>      ┆ <NA>      ┆ … ┆ <NA>      ┆ <NA>     ┆ <NA>      ┆ *** DATE: │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 2025-01-1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6         │
# │ 16230.103 ┆ <NA>      ┆ <NA>      ┆ <NA>      ┆ … ┆ <NA>      ┆ <NA>     ┆ <NA>      ┆ *** EXP_S │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ TART_TIME │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ STAMP:173 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 703…      │
# │ 16231.672 ┆ <NA>      ┆ <NA>      ┆ <NA>      ┆ … ┆ <NA>      ┆ <NA>     ┆ <NA>      ┆ *** SESSI │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ON_ID:1   │
# │ 16233.250 ┆ <NA>      ┆ <NA>      ┆ <NA>      ┆ … ┆ <NA>      ┆ <NA>     ┆ <NA>      ┆ *** PARTI │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ CIPANT_ID │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ :002      │
# │ 16234.806 ┆ <NA>      ┆ <NA>      ┆ <NA>      ┆ … ┆ <NA>      ┆ <NA>     ┆ <NA>      ┆ *** DATAS │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ET_TYPE:p │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ilot_sess │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ion…      │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …        ┆ …         ┆ …         │
# │ 7.8399e6  ┆ 10        ┆ 3         ┆ 3131      ┆ … ┆ right     ┆ True     ┆ False     ┆ prelimina │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ry        │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ answer:   │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ distracto │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ r…        │
# │ 7.8402e6  ┆ 10        ┆ 3         ┆ 3131      ┆ … ┆ left      ┆ True     ┆ True      ┆ prelimina │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ry        │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ answer:   │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ target_ke │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ y         │
# │ 7.8409e6  ┆ 10        ┆ 3         ┆ 3131      ┆ … ┆ space     ┆ True     ┆ True      ┆ prelimina │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ry        │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ answer:   │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ final_con │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ f…        │
# │ 7.8409e6  ┆ 10        ┆ 3         ┆ 3131      ┆ … ┆ left      ┆ True     ┆ True      ┆ FINAL     │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ ANSWER:   │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ correct   │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ answer i… │
# │ 7.8779e6  ┆ <NA>      ┆ <NA>      ┆ final_scr ┆ … ┆ 7877869.7 ┆ False    ┆ <NA>      ┆ stop      │
# │           ┆           ┆           ┆ een       ┆   ┆ 65399998  ┆          ┆           ┆ showing:  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ final_scr │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ een       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴──────────┴───────────┴───────────┘

# %%
stimulus_frame = sanity.logfile.filter(
              (pl.col("stimulus_number") == f"{11}")
            )
stimulus_frame.write_csv("stimulus_frame.csv")
stimulus_frame

# %%
print(stimuli)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(stimuli)
#
# NameError: name 'stimuli' is not defined

# %%
def check_all_screens_logfile(logfile: pl, stimuli: Stimulus):
    """ checking if all screens, where ET data is tracked are present in the log file"""
    for stimulus in stimuli:
        print(f"Checking {stimulus.name} in Logfile")
        trial_id = logfile.filter((pl.col("stimulus_number") == f"{stimulus.id}")).item(0, "trial_number") # get the trial number for the stimulus as ratingscreens don't have an entry in the stimulus_number column
      
        stimulus_frame = logfile.filter(
              (pl.col("trial_number") == f"{trial_id}")
            )
        #print(stimulus_frame)
        # check if all pages are present        
        for page in stimulus.pages:
            if f"{page.number}" not in stimulus_frame["page_number"].to_list():
                print(f"Missing page {stimulus.name} {page.number} in Logfile")  
                sanity.report_to_file(f" {stimulus.name}: Missing page{page.number} in Logfile", sanity.report_file)
        # check if all questions are present              
        for question in stimulus.questions:
            if f"{question.id}" not in stimulus_frame["page_number"].to_list() and f"{question.id[1:]}" not in stimulus_frame["page_number"].to_list():
                print(f"{stimulus.name}: Missing question_{question.id} in Logfile")
                sanity.report_to_file(f"{stimulus.name}: Missing question_{question.id} in Logfile", sanity.report_file)
               # print(stimulus_frame["screen"])
                
        for rating in stimulus.ratings:
            if f"{rating.name}" not in stimulus_frame["page_number"].to_list():
                print(f"{stimulus.name}: Missing rating screen {rating.name}")
                sanity.report_to_file(f"{stimulus.name}: Missing rating screen {rating.name} in Logfile", sanity.report_file)
               
check_all_screens_logfile(sanity.logfile, stimuli)
# Out:
# Checking PopSci_MultiplEYE in Logfile
# Checking Ins_HumanRights in Logfile
# Checking Ins_LearningMobility in Logfile
# Checking Lit_Alchemist in Logfile
# Checking Lit_MagicMountain in Logfile
# Checking Lit_Solaris in Logfile
# Checking Lit_BrokenApril in Logfile
# Checking Arg_PISACowsMilk in Logfile
# Checking Arg_PISARapaNui in Logfile
# Checking PopSci_Caveman in Logfile
# Checking Enc_WikiMoon in Logfile
# Checking Lit_NorthWind in Logfile

# %% [markdown]
# ## check if all pages screens ect are present in ASC file

# %%
def check_all_screens(gaze, stimuli):
    """ checking if all screens, where ET data is tracked are present in the gaze data frame, which is based on the ASC file
    it checks for all stimuli, if all pages and questions screens are present;it does not check for valditaion, calibration, instructions, etc.
    """
    for stimulus in stimuli:
        print(f"Checking {stimulus.name}")
        stimulus_frame = gaze.frame.filter(
              (pl.col("stimulus") == f"{stimulus.name}_{stimulus.id}")
            ).unique("screen")
        # check if all pages are present        
        for page in stimulus.pages:
            if f"page_{page.number}" not in stimulus_frame["screen"].to_list():
                print(f"Missing page {page.number}")  
                sanity.report_to_file(f"Missing page {page.number} in asc file", sanity.report_file)
        # check if all questions are present              
        for question in stimulus.questions:
            if f"question_{question.id}" not in stimulus_frame["screen"].to_list() and f"question_{question.id[1:]}" not in stimulus_frame["screen"].to_list():
                print(f"Missing question_{question.id}")
                sanity.report_to_file(f"Missing question_{question.id} in asc file",sanity.report_file)
                print(stimulus_frame["screen"])
                
        for rating in stimulus.ratings:
            if f"{rating.name}" not in stimulus_frame["screen"].to_list():
                print(f"Missing instruction {rating.name}")
                sanity.report_to_file(f"Missing rating {rating.name} in asc file",sanity.report_file)
            else: 
                print(f"Rating {rating.name} screens found")
                                
check_all_screens(gaze, stimuli)
# Out:
# Checking PopSci_MultiplEYE
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Ins_HumanRights
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Ins_LearningMobility
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Lit_Alchemist
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Lit_MagicMountain
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Lit_Solaris
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Lit_BrokenApril
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Arg_PISACowsMilk
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Arg_PISARapaNui
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking PopSci_Caveman
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Enc_WikiMoon
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found
# Checking Lit_NorthWind
# Rating subject_difficulty_screen screens found
# Rating familiarity_rating_screen_1 screens found
# Rating familiarity_rating_screen_2 screens found

# %% [markdown]
# ## Checking the order of the experiment

# %%
def load_messages(asc_file: Path, REGEX):
    with open(asc_file, "r", encoding="utf-8") as f:
        lines = f.readlines()
    messages = []
    for line in lines:
        match = re.match(REGEX, line)
        if match:
            messages.append(match.groupdict())
    return messages

#REGEX = r'MSG\s+(?P<timestamp>\d+[.]?\d*)\s+(?P<message>\w+)'
REGEX = r'MSG\s+(?P<timestamp>\d+[.]?\d*)\s+(?P<message>.*)'

messages = load_messages(sanity002.asc_file, REGEX)

# %%
print(messages)
# Out:
# [{'timestamp': '7026492.0', 'message': '!CMD select_parser_configuration 0'}, {'timestamp': '7026528.0', 'message': 'var initial eye_used right'}, {'timestamp': '7026605.0', 'message': 'welcome_screen'}, {'timestamp': '8701997.0', 'message': 'informed_consent_screen'}, {'timestamp': '8723499.0', 'message': 'start_experiment'}, {'timestamp': '8723499.0', 'message': 'stimulus_order_version: 6'}, {'timestamp': '8723500.0', 'message': 'showing_instruction_screen_1'}, {'timestamp': '8785495.0', 'message': 'showing_instruction_screen_2'}, {'timestamp': '8882855.0', 'message': 'showing_instruction_screen_3'}, {'timestamp': '8894660.0', 'message': 'camera_setup_screen'}, {'timestamp': '8977204.0', 'message': 'DISPLAY_COORDS 0 0 1584 1198'}, {'timestamp': '9129603.0', 'message': '!CAL '}, {'timestamp': '9129603.0', 'message': '!CAL Calibration points:  '}, {'timestamp': '9129603.0', 'message': '!CAL -20.2, -72.6        -0,      9   '}, {'timestamp': '9129603.0', 'message': '!CAL -23.3, -96.5        -0,  -2090   '}, {'timestamp': '9129603.0', 'message': '!CAL -18.3, -50.5        -0,   2108   '}, {'timestamp': '9129603.0', 'message': '!CAL -56.4, -71.6     -3961,      9   '}, {'timestamp': '9129603.0', 'message': '!CAL  14.7, -71.7      3961,      9   '}, {'timestamp': '9129603.0', 'message': '!CAL -60.1, -94.4     -3961,  -2090   '}, {'timestamp': '9129603.0', 'message': '!CAL  68.6, -145.9      3961,  -2090   '}, {'timestamp': '9129603.0', 'message': '!CAL -52.8, -49.8     -3962,   2108   '}, {'timestamp': '9129603.0', 'message': '!CAL  15.1, -49.3      3962,   2108   '}, {'timestamp': '9129603.0', 'message': '!CAL  0.0,  0.0         0,      0   '}, {'timestamp': '9129603.0', 'message': '!CAL eye check box: (L,R,T,B)'}, {'timestamp': '9129603.0', 'message': '!CAL href cal range: (L,R,T,B)'}, {'timestamp': '9129603.0', 'message': '!CAL Cal coeff:(X=a+bx+cy+dxx+eyy,Y=f+gx+goaly+ixx+jyy)'}, {'timestamp': '9129603.0', 'message': '!CAL Prenormalize: offx, offy = -20.194 -72.57'}, {'timestamp': '9129603.0', 'message': '!CAL Quadrant center: centx, centy = '}, {'timestamp': '9129603.0', 'message': '!CAL Corner correction:'}, {'timestamp': '9129603.0', 'message': '!CAL Gains: cx:135.436 lx:124.746 rx:141.344'}, {'timestamp': '9129603.0', 'message': '!CAL Gains: cy:113.138 ty:51.246 by:125.280'}, {'timestamp': '9129603.0', 'message': '!CAL Resolution (upd) at screen center: X=1.9, Y=2.3'}, {'timestamp': '9129603.0', 'message': '!CAL Gain Change Proportion: X: 0.133 Y: 1.445'}, {'timestamp': '9129603.0', 'message': '!CAL Gain Ratio (Gy/Gx) = 0.835'}, {'timestamp': '9129603.0', 'message': '!CAL Bad Y/X gain ratio: 0.835 '}, {'timestamp': '9129603.0', 'message': '!CAL PCR gain ratio(x,y) = 2.040, 1.804'}, {'timestamp': '9129603.0', 'message': '!CAL CR gain match(x,y) = 1.010, 1.010'}, {'timestamp': '9129603.0', 'message': '!CAL Slip rotation correction OFF'}, {'timestamp': '9129604.0', 'message': '!CAL CALIBRATION HV9 R RIGHT   GOOD '}, {'timestamp': '9201781.0', 'message': '!CAL '}, {'timestamp': '9201781.0', 'message': '!CAL Calibration points:  '}, {'timestamp': '9201781.0', 'message': '!CAL -14.6, -66.4        -0,      9   '}, {'timestamp': '9201781.0', 'message': '!CAL -16.6, -91.1        -0,  -2090   '}, {'timestamp': '9201781.0', 'message': '!CAL -13.5, -43.6        -0,   2108   '}, {'timestamp': '9201781.0', 'message': '!CAL -49.3, -66.1     -3961,      9   '}, {'timestamp': '9201781.0', 'message': '!CAL  19.3, -63.9      3961,      9   '}, {'timestamp': '9201781.0', 'message': '!CAL -52.3, -90.8     -3961,  -2090   '}, {'timestamp': '9201781.0', 'message': '!CAL  19.5, -89.8      3961,  -2090   '}, {'timestamp': '9201781.0', 'message': '!CAL -46.7, -44.0     -3962,   2108   '}, {'timestamp': '9201781.0', 'message': '!CAL  17.9, -40.0      3962,   2108   '}, {'timestamp': '9201781.0', 'message': '!CAL  0.0,  0.0         0,      0   '}, {'timestamp': '9201781.0', 'message': '!CAL eye check box: (L,R,T,B)'}, {'timestamp': '9201781.0', 'messa ...

# %%
gaze = sanity002.get_frame()

# %%
sanity002.stimuli_order
# Out:
# [13, 7, 6, 11, 8, 12, 10, 9, 2, 1, 4, 3]

# %%
# check order in ASC file based on messages
def check_instructions(messages: list, stimuli: Stimulus, sanity: Sanity):
    
    messages_only = [d.get('message') for d in messages]
    one_time_screens = ['welcome_screen', 'informed_consent_screen', 'start_experiment', 'stimulus_order_version', 'showing_instruction_screen_1', 'showing_instruction_screen_2', 'showing_instruction_screen_3', 'camera_setup_screen', 'practice_text_starting_screen', 'start_recording_PRACTICE_trial_1_stimulus_Enc_WikiMoon_13_page_1','stop_recording_PRACTICE_trial_1_stimulus_Enc_WikiMoon_13_page_1','start_recording_PRACTICE_trial_1_stimulus_Enc_WikiMoon_13_page_2','stop_recording_PRACTICE_trial_1_stimulus_Enc_WikiMoon_13_page_2','start_recording_PRACTICE_trial_1_stimulus_Enc_WikiMoon_13_page_2','start_recording_PRACTICE_trial_2_stimulus_Lit_NorthWind_7_page_1', 'stop_recording_PRACTICE_trial_2_stimulus_Lit_NorthWind_7_page_1','transition_screen', 'final_validation', 'show_final_screen', 'obligatory_break', 'obligatory_break_end']
    optional_screens = ['empty_screen', 'optional_break_screen', 'fixation_trigger:skipped_by_experimenter', 'fixation_trigger:experimenter_calibration_triggered', 'optional_break', 'optional_break_duration', 'obligatory_break']
    reoccuring_screens = ['showing_subject_difficulty_screen', 'showing_familiarity_rating_screen_1','showing_familiarity_rating_screen_2']
    
    
    def _check_validation_screen(last_index, index_next_stimulus):
        #print(last_index, index_next_stimulus)
        if "validation_before_stimulus" not in messages_only[last_index:index_next_stimulus] and "final_validation" not in messages_only[last_index:index_next_stimulus]:
            print(f"{stimulus.name}: Missing validation screen")
            sanity.report_to_file(f"{stimulus.name}: Missing validation screen in asc file", sanity.report_file)
        #else:
          #  print(f"{stimulus.name}: Validation screen found")
          #  val_index = [msg.get("message") for msg in messages[last_index:index_next_stimulus]].index("validation_before_stimulus")
           # val_timestamp =messages[last_index:index_next_stimulus][val_index].get("timestamp")
           # print("val_timestamp:", val_timestamp)
            
    def _get_stimulus(id, next_id=None):
        right_stimulus = None
        next_stimulus = None
        for stimulus in stimuli:
            if stimulus.id == id:
                right_stimulus = stimulus
            if stimulus.id == next_id:
                next_stimulus = stimulus
       
        return right_stimulus, next_stimulus
            
    def _check_instruction_screens(last_index, index_next_stimulus):
        for instruction in reoccuring_screens:
            if f"{instruction}" not in messages_only[last_index:index_next_stimulus]:
                print(f"Missing instruction {instruction}")
                sanity.report_to_file(f"Missing instruction {instruction} in asc file", sanity.report_file)
           # else:
                #print(f"Rating {instruction} screens found")
    
                
    def reoccuring_msg(trial):
        index_obligatory_break = messages_only.index("obligatory_break")
        pattern = f"_trial_{trial}_stimulus_{stimulus.name}_{stimulus.id}"
        last_index = messages_only.index(f"start_recording{pattern}_page_1")
        last_timestamp = messages[last_index].get("timestamp")
        #$print(last_timestamp)
        if next_stimulus:
            index_next_stimulus = messages_only.index(f"start_recording_trial_{trial+1}_stimulus_{next_stimulus.name}_{next_stimulus.id}_page_1")
            
            if index_obligatory_break < index_next_stimulus  and index_obligatory_break > last_index:
                break_timestamp = messages[index_obligatory_break].get("timestamp")
                sanity.report_to_file(f"{trial}: {stimulus.name}: {round(((float(break_timestamp)-float(last_timestamp))/60000), 2)} minutes", sanity.report_file)
                next_timestamp = messages[index_next_stimulus].get("timestamp")
                sanity.report_to_file(f"obligatory break: {round(((float(next_timestamp)-float(break_timestamp))/60000), 2)} minutes", sanity.report_file)      
                
            else:
                next_timestamp = messages[index_next_stimulus].get("timestamp")
                sanity.report_to_file(f"{trial}:  {stimulus.name}: {round(((float(next_timestamp)-float(last_timestamp))/60000), 2)} minutes", sanity.report_file)
            
        else:
            index_next_stimulus = len(messages_only)-1
            next_timestamp = messages[index_next_stimulus].get("timestamp")
        #print(next_timestamp)
        #print(round(((float(next_timestamp)-float(last_timestamp))/60000), 2))
            sanity.report_to_file(f"{trial}:  {stimulus.name}: {round(((float(next_timestamp)-float(last_timestamp))/60000), 2)} minutes", sanity.report_file)
       
                
        msg_to_find = ["start_recording","screen_image_onset", "screen_image_offset", "stop_recording"]
    
            
        for page in stimulus.pages:
            for msg in msg_to_find:
                if msg.startswith("screen"):
                    current_pattern = f"page_{msg}"
                else:
                    current_pattern = f"{msg}{pattern}_page_{page.number}"
                    
                if current_pattern not in messages_only[last_index:index_next_stimulus]:
                    print(f"{stimulus.name}: Missing {current_pattern} Messages in ASC file")
                else:
                    last_index = messages_only[last_index:index_next_stimulus].index(current_pattern) + last_index
                            
        _check_instruction_screens(last_index, index_next_stimulus)  
       
        for question in stimulus.questions:
            for msg in msg_to_find:
                if msg.startswith("screen"): # get the cleaned questio_id (removed zero at the start, if present)
                    current_pattern = f"question_{msg}"
                else:
                    if question.id.startswith("0"):
                        question_id = question.id[1:]
                    else:
                        question_id = question.id
                        
                    current_pattern = f"{msg}{pattern}_question_{question_id}"
                    
                if current_pattern not in messages_only[last_index:index_next_stimulus]:
                    print(f"{stimulus.name}: Missing {current_pattern} Messages in ASC file")
                # else:
                  #  print(f"{stimulus.name}: {current_pattern} Messages is in ASC file")
                    
                    
        _check_validation_screen(last_index, index_next_stimulus)
                
    for trial, id in enumerate(sanity.stimuli_order[2:]): # for id in vars_dict["stimulus_order]: # skip th e practice trials
        try:
            stimulus, next_stimulus = _get_stimulus(id, sanity.stimuli_order[2:][trial+1]) # also get next stimulus to check for the reoccuring screens
        except IndexError:
            print("Last stimulus")
            stimulus, next_stimulus = _get_stimulus(id, None)
            
        print(f"Checking {stimulus.name}")
        reoccuring_msg(trial+1) # add one because the first trial  has number 1 not 0 
    
                
    for one_time_screen in one_time_screens:
        if f"{one_time_screen}" not in messages_only:
            found = False
            for message in messages_only:
                if message.startswith(one_time_screen):
                    #print(f"found it {message}")
                    found = True
                    
            if not found:    
                print(f"Missing screen {one_time_screen}")
                sanity.report_to_file(f"Missing one time screen {one_time_screen} in asc file", sanity.report_file)
       # else:
        #    print(f"{one_time_screen} found")
            
    for optional_screen in optional_screens:
        
        indices = list(filter(lambda i: messages_only[i] == optional_screen, range(len(messages_only))))
        if indices:
            sanity.report_to_file(f"{messages[indices[0]]['message']} found {len(indices)} times", sanity.report_file)
        
        for index in indices:
            if optional_screen == "optional_break" or optional_screen == "obligatory_break":
                msg =  messages[index+2]
                sanity.report_to_file(f"{msg['message']} found at {msg['timestamp']}", sanity.report_file)
                print(f"{msg['message']} found at {msg['timestamp']}")
                
                
            else:
                sanity.report_to_file(f"{optional_screen['message']} found at {optional_screen['timestamp']}", sanity.report_file)
                print(f"{optional_screen['message']} found at {optional_screen['timestamp']}")

# %%
check_instructions(messages, stimuli, sanity002)
# Out:
# Checking Lit_MagicMountain
# Checking Arg_PISARapaNui
# Checking Lit_Solaris
# Checking PopSci_Caveman
# Checking Arg_PISACowsMilk
# Checking Lit_BrokenApril
# Checking Ins_HumanRights
# Checking PopSci_MultiplEYE
# Checking Lit_Alchemist
# Last stimulus
# Checking Ins_LearningMobility
# [712, 1231, 1777, 2168, 3124, 3477, 3937, 4231]
# optional_break_duration: 8094.963900002651 found at 10343038.0
# optional_break_duration: 4446.710999996867 found at 10899371.0
# optional_break_duration: 3038.8816999914125 found at 11424136.0
# optional_break_duration: 14734.705700000748 found at 11836806.0
# optional_break_duration: 2142.928300003521 found at 12960576.0
# optional_break_duration: 958.9155999859795 found at 13240191.0
# optional_break_duration: 1966.9461000012234 found at 14180041.0
# optional_break_duration: 1070.9741000020877 found at 14417736.0
# [2687]
# obligatory_break_duration: 269967.2572999988 found at 12549050.0

# %%
gaze._metadata
# Out:
# {'weekday': 'Thu',
#  'month': 'Jan',
#  'day': 16,
#  'time': '15:34:29',
#  'year': 2025,
#  'version_1': 'EYELINK II 1',
#  'version_2': 'EYELINK II CL v5.12 May 12 2017',
#  'resolution': (1585, 1199),
#  'tracking_mode': 'CR',
#  'sampling_rate': 1000.0,
#  'file_sample_filter': '2',
#  'link_sample_filter': '1',
#  'tracked_eye': 'R',
#  'mount_configuration': {'mount_type': 'Desktop',
#   'head_stabilization': 'stabilized',
#   'eyes_recorded': 'monocular',
#   'short_name': 'MTABLER'},
#  'pupil_data_type': 'AREA',
#  'version_number': '5.12',
#  'model': 'EyeLink 1000 Plus',
#  'datetime': datetime.datetime(2025, 1, 16, 15, 34, 29),
#  'calibrations': [{'timestamp': '9129603.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9201781.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9448289.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9481210.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '9915402.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '10363669.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '10928705.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '11471625.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '11862009.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '12576792.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '13261434.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '14206068.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '14452185.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'}],
#  'validations': [{'timestamp': '9299961.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'FAIR ERROR',
#    'validation_score_avg': '0.49',
#    'validation_score_max': '1.94'},
#   {'timestamp': '9497011.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.23',
#    'validation_score_max': '0.47'},
#   {'timestamp': '9900225.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.27',
#    'validation_score_max': '0.53'},
#   {'timestamp': '9930932.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.19',
#    'validation_score_max': '0.66'},
#   {'timestamp': '10374779.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.39'},
#   {'timestamp': '10943067.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.18',
#    'validation_score_max': '0.44'},
#   {'timestamp': '11456253.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.50'},
#   {'timestamp': '11488536.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.30',
#    'validation_score_max': '0.59'},
#   {'timestamp': '11875001.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.13',
#    'validation_score_max': '0.60'},
#   {'timestamp': '12593643.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.20',
#    'validation_score_max': '0.39'},
#   {'timestamp': '12980746.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.30',
#    'validation_score_max': '0.69'},
#   {'timestamp': '13275653.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.16',
#    'validation_score_max': '0.51'},
#   {'timestamp': '14219957.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.23',
#    'validation_score_max': '0.98'},
#   {'timestamp': '14434447.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.85'},
#   {'timestamp': '14470997.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.29',
#    'validation_score_max': '1.37'},
#   {'timestamp': '14873568.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.42',
#    'validation_score_max': '1.14'}],
#  'blinks': [{'start_timestamp': 9545980.0,
#    'stop_timestamp': 9546041.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 9548344.0,
#    'stop_timestamp': 9548435.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 9556683.0,
#    'stop_timestamp': 9556705.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 9560517.0,
#    'stop_timestamp': 9560683.0,
#    'duration_ms': 167.0,
#    'num_samples': 0},
#   {'start_timestamp': 9562284.0,
#    'stop_timestamp': 9562381.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 9572180.0,
#    'stop_timestamp': 9572258.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 9577177.0,
#    'stop_timestamp': 9577237.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 9580868.0,
#    'stop_timestamp': 9580965.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 9583209.0,
#    'stop_timestamp': 9583290.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 9588451.0,
#    'stop_timestamp': 9588505.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 9593662.0,
#    'stop_timestamp': 9593745.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 9598803.0,
#    'stop_timestamp': 9598878.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 9604662.0,
#    'stop_timestamp': 9604740.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 9610928.0,
#    'stop_timestamp': 9611027.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 9617980.0,
#    'stop_timestamp': 9618054.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 9625564.0,
#    'stop_timestamp': 9625658.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 9629991.0,
#    'stop_timestamp': 9630087.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 9632873.0,
#    'stop_timestamp': 9632979.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 9643868.0,
#    'stop_timestamp': 9643915.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 9644251.0,
#    'stop_timestamp': 9644421.0,
#    'duration_ms': 171.0,
#    'num_samples': 0},
#   {'start_timestamp': 9648928.0,
#    'stop_timestamp': 9649001.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 9654145.0,
#    'stop_timestamp': 9654229.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 9655968.0,
#    'stop_timestamp': 9656055.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 9666238.0,
#    'stop_timestamp': 9666321.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 9673892.0,
#    'stop_timestamp': 9673978.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 9679237.0,
#    'stop_timestamp': 9679342.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 9691195.0,
#    'stop_timestamp': 9691213.0,
#    'duration_ms': 19.0,
#    'num_samples': 0},
#   {'start_timestamp': 9692917.0,
#    'stop_timestamp': 9692999.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 9694862.0,
#    'stop_timestamp': 9694958.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 9704707.0,
#    'stop_timestamp': 9704775.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 9706742.0,
#    'stop_timestamp': 9706829.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 9724936.0,
#    'stop_timestamp': 9725014.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 9737581.0,
#    'stop_timestamp': 9737705.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 9746267.0,
#    'stop_timestamp': 9746286.0,
#    'duration_ms': 20.0,
#    'num_samples': 0},
#   {'start_timestamp': 9747540.0,
#    'stop_timestamp': 9747671.0,
#    'duration_ms': 132.0,
#    'num_samples': 0},
#   {'start_timestamp': 9752178.0,
#    'stop_timestamp': 9752192.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 9757077.0,
#    'stop_timestamp': 9757107.0,
#    'duration_ms': 31.0,
#    'num_samples': 0},
#   {'start_timestamp': 9762755.0,
#    'stop_timestamp': 9762803.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 9769558.0,
#    'stop_timestamp': 9769616.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 9771784.0,
#    'stop_timestamp': 9771823.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 9772248.0,
#    'stop_timestamp': 9772376.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 9776761.0,
#    'stop_timestamp': 9776850.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 9781515.0,
#    'stop_timestamp': 9781603.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 9795673.0,
#    'stop_timestamp': 9795737.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 9815204.0,
#    'stop_timestamp': 9815289.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 9827416.0,
#    'stop_timestamp': 9827488.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 9945834.0,
#    'stop_timestamp': 9945834.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 9958905.0,
#    'stop_timestamp': 9958930.0,
#    'duration_ms': 26.0,
#    'num_samples': 0},
#   {'start_timestamp': 9970452.0,
#    'stop_timestamp': 9970508.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 9974353.0,
#    'stop_timestamp': 9974425.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 9988058.0,
#    'stop_timestamp': 9988128.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 9994104.0,
#    'stop_timestamp': 9994172.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10011175.0,
#    'stop_timestamp': 10011229.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 10017041.0,
#    'stop_timestamp': 10017133.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10032229.0,
#    'stop_timestamp': 10032386.0,
#    'duration_ms': 158.0,
#    'num_samples': 0},
#   {'start_timestamp': 10035072.0,
#    'stop_timestamp': 10035121.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 10040696.0,
#    'stop_timestamp': 10040737.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 10046008.0,
#    'stop_timestamp': 10046102.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 10052676.0,
#    'stop_timestamp': 10052754.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 10060573.0,
#    'stop_timestamp': 10060661.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 10075821.0,
#    'stop_timestamp': 10075866.0,
#    'duration_ms': 46.0,
#    'num_samples': 0},
#   {'start_timestamp': 10077753.0,
#    'stop_timestamp': 10077835.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 10078941.0,
#    'stop_timestamp': 10079069.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 10082699.0,
#    'stop_timestamp': 10082779.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 10090468.0,
#    'stop_timestamp': 10090536.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10091414.0,
#    'stop_timestamp': 10091533.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 10096482.0,
#    'stop_timestamp': 10096577.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10103345.0,
#    'stop_timestamp': 10103429.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10109577.0,
#    'stop_timestamp': 10109666.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10118282.0,
#    'stop_timestamp': 10118371.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10121437.0,
#    'stop_timestamp': 10121514.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 10125059.0,
#    'stop_timestamp': 10125137.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 10128785.0,
#    'stop_timestamp': 10128852.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 10131548.0,
#    'stop_timestamp': 10131643.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10137852.0,
#    'stop_timestamp': 10137967.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10150083.0,
#    'stop_timestamp': 10150145.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 10152010.0,
#    'stop_timestamp': 10152109.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 10158513.0,
#    'stop_timestamp': 10158646.0,
#    'duration_ms': 134.0,
#    'num_samples': 0},
#   {'start_timestamp': 10165372.0,
#    'stop_timestamp': 10165438.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10169472.0,
#    'stop_timestamp': 10169542.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 10199234.0,
#    'stop_timestamp': 10199320.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 10212082.0,
#    'stop_timestamp': 10212172.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10230139.0,
#    'stop_timestamp': 10230180.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 10237392.0,
#    'stop_timestamp': 10237397.0,
#    'duration_ms': 6.0,
#    'num_samples': 0},
#   {'start_timestamp': 10240868.0,
#    'stop_timestamp': 10240970.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10252208.0,
#    'stop_timestamp': 10252277.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 10259699.0,
#    'stop_timestamp': 10259741.0,
#    'duration_ms': 43.0,
#    'num_samples': 0},
#   {'start_timestamp': 10273010.0,
#    'stop_timestamp': 10273087.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 10280844.0,
#    'stop_timestamp': 10280946.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10284227.0,
#    'stop_timestamp': 10284276.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 10286724.0,
#    'stop_timestamp': 10286800.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 10290632.0,
#    'stop_timestamp': 10290707.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 10291947.0,
#    'stop_timestamp': 10292044.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10295194.0,
#    'stop_timestamp': 10295360.0,
#    'duration_ms': 167.0,
#    'num_samples': 0},
#   {'start_timestamp': 10297592.0,
#    'stop_timestamp': 10297714.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 10299511.0,
#    'stop_timestamp': 10299597.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 10303469.0,
#    'stop_timestamp': 10303573.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 10305769.0,
#    'stop_timestamp': 10305864.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10312248.0,
#    'stop_timestamp': 10312331.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 10318430.0,
#    'stop_timestamp': 10318528.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 10319714.0,
#    'stop_timestamp': 10319856.0,
#    'duration_ms': 143.0,
#    'num_samples': 0},
#   {'start_timestamp': 10333333.0,
#    'stop_timestamp': 10333430.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10382514.0,
#    'stop_timestamp': 10382603.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10385769.0,
#    'stop_timestamp': 10385861.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10388923.0,
#    'stop_timestamp': 10388983.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 10404001.0,
#    'stop_timestamp': 10404056.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 10414837.0,
#    'stop_timestamp': 10414901.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 10426749.0,
#    'stop_timestamp': 10426831.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 10430197.0,
#    'stop_timestamp': 10430255.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 10434700.0,
#    'stop_timestamp': 10434768.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10436025.0,
#    'stop_timestamp': 10436126.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 10439187.0,
#    'stop_timestamp': 10439239.0,
#    'duration_ms': 53.0,
#    'num_samples': 0},
#   {'start_timestamp': 10441788.0,
#    'stop_timestamp': 10441890.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10448296.0,
#    'stop_timestamp': 10448417.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 10452434.0,
#    'stop_timestamp': 10452519.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 10455000.0,
#    'stop_timestamp': 10455088.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 10457753.0,
#    'stop_timestamp': 10457836.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 10467846.0,
#    'stop_timestamp': 10467964.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 10474806.0,
#    'stop_timestamp': 10474873.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 10479362.0,
#    'stop_timestamp': 10479451.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 10487318.0,
#    'stop_timestamp': 10487375.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 10504747.0,
#    'stop_timestamp': 10504787.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 10510076.0,
#    'stop_timestamp': 10510157.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 10512697.0,
#    'stop_timestamp': 10512711.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 10519905.0,
#    'stop_timestamp': 10519919.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 10521409.0,
#    'stop_timestamp': 10521513.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 10533102.0,
#    'stop_timestamp': 10533181.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10542170.0,
#    'stop_timestamp': 10542263.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 10548933.0,
#    'stop_timestamp': 10548988.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 10556728.0,
#    'stop_timestamp': 10556775.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 10567461.0,
#    'stop_timestamp': 10567534.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 10569374.0,
#    'stop_timestamp': 10569459.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 10571035.0,
#    'stop_timestamp': 10571114.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10572579.0,
#    'stop_timestamp': 10572645.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10580007.0,
#    'stop_timestamp': 10580072.0,
#    'duration_ms': 66.0,
#    'num_samples': 0},
#   {'start_timestamp': 10585831.0,
#    'stop_timestamp': 10585902.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 10593431.0,
#    'stop_timestamp': 10593574.0,
#    'duration_ms': 144.0,
#    'num_samples': 0},
#   {'start_timestamp': 10596068.0,
#    'stop_timestamp': 10596159.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 10598859.0,
#    'stop_timestamp': 10598955.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 10612081.0,
#    'stop_timestamp': 10612173.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10620750.0,
#    'stop_timestamp': 10620895.0,
#    'duration_ms': 146.0,
#    'num_samples': 0},
#   {'start_timestamp': 10622132.0,
#    'stop_timestamp': 10622193.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 10625807.0,
#    'stop_timestamp': 10625866.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 10626171.0,
#    'stop_timestamp': 10626273.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 10626488.0,
#    'stop_timestamp': 10626587.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 10626876.0,
#    'stop_timestamp': 10626973.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10627166.0,
#    'stop_timestamp': 10627281.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10627492.0,
#    'stop_timestamp': 10627601.0,
#    'duration_ms': 110.0,
#    'num_samples': 0},
#   {'start_timestamp': 10629593.0,
#    'stop_timestamp': 10629666.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 10634448.0,
#    'stop_timestamp': 10634561.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 10640807.0,
#    'stop_timestamp': 10640874.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 10643398.0,
#    'stop_timestamp': 10643533.0,
#    'duration_ms': 136.0,
#    'num_samples': 0},
#   {'start_timestamp': 10653029.0,
#    'stop_timestamp': 10653144.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10661129.0,
#    'stop_timestamp': 10661213.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10665603.0,
#    'stop_timestamp': 10665669.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10669566.0,
#    'stop_timestamp': 10669651.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 10681442.0,
#    'stop_timestamp': 10681532.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10691049.0,
#    'stop_timestamp': 10691130.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 10693162.0,
#    'stop_timestamp': 10693235.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 10704765.0,
#    'stop_timestamp': 10704880.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 10705602.0,
#    'stop_timestamp': 10705705.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 10706819.0,
#    'stop_timestamp': 10706915.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 10710365.0,
#    'stop_timestamp': 10710509.0,
#    'duration_ms': 145.0,
#    'num_samples': 0},
#   {'start_timestamp': 10713890.0,
#    'stop_timestamp': 10713929.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 10714117.0,
#    'stop_timestamp': 10714207.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10715026.0,
#    'stop_timestamp': 10715147.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 10719611.0,
#    'stop_timestamp': 10719677.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10724082.0,
#    'stop_timestamp': 10724161.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10726210.0,
#    'stop_timestamp': 10726318.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 10729183.0,
#    'stop_timestamp': 10729321.0,
#    'duration_ms': 139.0,
#    'num_samples': 0},
#   {'start_timestamp': 10729773.0,
#    'stop_timestamp': 10729896.0,
#    'duration_ms': 124.0,
#    'num_samples': 0},
#   {'start_timestamp': 10741754.0,
#    'stop_timestamp': 10741884.0,
#    'duration_ms': 131.0,
#    'num_samples': 0},
#   {'start_timestamp': 10751788.0,
#    'stop_timestamp': 10751878.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 10755579.0,
#    'stop_timestamp': 10755658.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 10758616.0,
#    'stop_timestamp': 10758722.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 10761315.0,
#    'stop_timestamp': 10761412.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 10775826.0,
#    'stop_timestamp': 10775920.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 10779579.0,
#    'stop_timestamp': 10779699.0,
#    'duration_ms': 121.0,
#    'num_samples': 0},
#   {'start_timestamp': 10786494.0,
#    'stop_timestamp': 10786563.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 10791819.0,
#    'stop_timestamp': 10791885.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10795096.0,
#    'stop_timestamp': 10795164.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 10796861.0,
#    'stop_timestamp': 10796989.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 10800741.0,
#    'stop_timestamp': 10800821.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 10802629.0,
#    'stop_timestamp': 10802734.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 10808932.0,
#    'stop_timestamp': 10809016.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10810174.0,
#    'stop_timestamp': 10810362.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 10818883.0,
#    'stop_timestamp': 10818993.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 10821259.0,
#    'stop_timestamp': 10821353.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 10822082.0,
#    'stop_timestamp': 10822204.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 10829890.0,
#    'stop_timestamp': 10829914.0,
#    'duration_ms': 25.0,
#    'num_samples': 0},
#   {'start_timestamp': 10830448.0,
#    'stop_timestamp': 10830549.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 10841378.0,
#    'stop_timestamp': 10841481.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 10845368.0,
#    'stop_timestamp': 10845434.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 10850405.0,
#    'stop_timestamp': 10850526.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 10856873.0,
#    'stop_timestamp': 10856977.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 10858756.0,
#    'stop_timestamp': 10858892.0,
#    'duration_ms': 137.0,
#    'num_samples': 0},
#   {'start_timestamp': 10860233.0,
#    'stop_timestamp': 10860281.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 10860719.0,
#    'stop_timestamp': 10860814.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 10865837.0,
#    'stop_timestamp': 10865944.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 10872763.0,
#    'stop_timestamp': 10872910.0,
#    'duration_ms': 148.0,
#    'num_samples': 0},
#   {'start_timestamp': 10874902.0,
#    'stop_timestamp': 10874988.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 10878947.0,
#    'stop_timestamp': 10879043.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 10882333.0,
#    'stop_timestamp': 10882416.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 10891271.0,
#    'stop_timestamp': 10891376.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 10951855.0,
#    'stop_timestamp': 10951855.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 10956206.0,
#    'stop_timestamp': 10956266.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 10964856.0,
#    'stop_timestamp': 10964948.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 10972603.0,
#    'stop_timestamp': 10972664.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 10980229.0,
#    'stop_timestamp': 10980313.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 10981965.0,
#    'stop_timestamp': 10982089.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 10983609.0,
#    'stop_timestamp': 10983717.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 10995080.0,
#    'stop_timestamp': 10995138.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 10998020.0,
#    'stop_timestamp': 10998091.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 11000523.0,
#    'stop_timestamp': 11000622.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11003931.0,
#    'stop_timestamp': 11004016.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 11008984.0,
#    'stop_timestamp': 11009002.0,
#    'duration_ms': 19.0,
#    'num_samples': 0},
#   {'start_timestamp': 11017015.0,
#    'stop_timestamp': 11017016.0,
#    'duration_ms': 2.0,
#    'num_samples': 0},
#   {'start_timestamp': 11022428.0,
#    'stop_timestamp': 11022508.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11025326.0,
#    'stop_timestamp': 11025439.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 11028046.0,
#    'stop_timestamp': 11028077.0,
#    'duration_ms': 32.0,
#    'num_samples': 0},
#   {'start_timestamp': 11040801.0,
#    'stop_timestamp': 11040883.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 11047564.0,
#    'stop_timestamp': 11047631.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 11057214.0,
#    'stop_timestamp': 11057294.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11061941.0,
#    'stop_timestamp': 11061991.0,
#    'duration_ms': 51.0,
#    'num_samples': 0},
#   {'start_timestamp': 11070537.0,
#    'stop_timestamp': 11070537.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 11073195.0,
#    'stop_timestamp': 11073288.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11085492.0,
#    'stop_timestamp': 11085583.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 11089803.0,
#    'stop_timestamp': 11089875.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 11093608.0,
#    'stop_timestamp': 11093695.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 11105020.0,
#    'stop_timestamp': 11105137.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 11109272.0,
#    'stop_timestamp': 11109286.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 11116180.0,
#    'stop_timestamp': 11116270.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 11118978.0,
#    'stop_timestamp': 11119071.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11129040.0,
#    'stop_timestamp': 11129113.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 11132317.0,
#    'stop_timestamp': 11132387.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 11141254.0,
#    'stop_timestamp': 11141329.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 11147539.0,
#    'stop_timestamp': 11147622.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 11155339.0,
#    'stop_timestamp': 11155402.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 11160666.0,
#    'stop_timestamp': 11160732.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 11163111.0,
#    'stop_timestamp': 11163191.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11165071.0,
#    'stop_timestamp': 11165148.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11178605.0,
#    'stop_timestamp': 11178693.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 11188415.0,
#    'stop_timestamp': 11188507.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 11192281.0,
#    'stop_timestamp': 11192313.0,
#    'duration_ms': 33.0,
#    'num_samples': 0},
#   {'start_timestamp': 11194063.0,
#    'stop_timestamp': 11194182.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 11200451.0,
#    'stop_timestamp': 11200513.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 11202797.0,
#    'stop_timestamp': 11202884.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 11206492.0,
#    'stop_timestamp': 11206571.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 11213162.0,
#    'stop_timestamp': 11213255.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11216234.0,
#    'stop_timestamp': 11216329.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 11228019.0,
#    'stop_timestamp': 11228111.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 11231823.0,
#    'stop_timestamp': 11231907.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 11237856.0,
#    'stop_timestamp': 11237905.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 11240406.0,
#    'stop_timestamp': 11240482.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 11256426.0,
#    'stop_timestamp': 11256550.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 11259521.0,
#    'stop_timestamp': 11259599.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 11261930.0,
#    'stop_timestamp': 11262028.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 11264450.0,
#    'stop_timestamp': 11264501.0,
#    'duration_ms': 52.0,
#    'num_samples': 0},
#   {'start_timestamp': 11269035.0,
#    'stop_timestamp': 11269150.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 11271196.0,
#    'stop_timestamp': 11271305.0,
#    'duration_ms': 110.0,
#    'num_samples': 0},
#   {'start_timestamp': 11273169.0,
#    'stop_timestamp': 11273264.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 11274363.0,
#    'stop_timestamp': 11274476.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 11281393.0,
#    'stop_timestamp': 11281482.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 11289442.0,
#    'stop_timestamp': 11289499.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 11293001.0,
#    'stop_timestamp': 11293103.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11295978.0,
#    'stop_timestamp': 11296106.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 11304523.0,
#    'stop_timestamp': 11304624.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 11310162.0,
#    'stop_timestamp': 11310239.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11313689.0,
#    'stop_timestamp': 11313813.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 11317398.0,
#    'stop_timestamp': 11317535.0,
#    'duration_ms': 138.0,
#    'num_samples': 0},
#   {'start_timestamp': 11331576.0,
#    'stop_timestamp': 11331687.0,
#    'duration_ms': 112.0,
#    'num_samples': 0},
#   {'start_timestamp': 11335225.0,
#    'stop_timestamp': 11335347.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 11340749.0,
#    'stop_timestamp': 11340787.0,
#    'duration_ms': 39.0,
#    'num_samples': 0},
#   {'start_timestamp': 11352176.0,
#    'stop_timestamp': 11352271.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 11361292.0,
#    'stop_timestamp': 11361394.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11372032.0,
#    'stop_timestamp': 11372140.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 11378804.0,
#    'stop_timestamp': 11378827.0,
#    'duration_ms': 24.0,
#    'num_samples': 0},
#   {'start_timestamp': 11388391.0,
#    'stop_timestamp': 11388490.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11394074.0,
#    'stop_timestamp': 11394133.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 11396528.0,
#    'stop_timestamp': 11396632.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11405260.0,
#    'stop_timestamp': 11405323.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 11414744.0,
#    'stop_timestamp': 11414837.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11495334.0,
#    'stop_timestamp': 11495389.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 11498959.0,
#    'stop_timestamp': 11499053.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 11502549.0,
#    'stop_timestamp': 11502626.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11507209.0,
#    'stop_timestamp': 11507291.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 11513517.0,
#    'stop_timestamp': 11513613.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 11515647.0,
#    'stop_timestamp': 11515757.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 11529407.0,
#    'stop_timestamp': 11529490.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 11536531.0,
#    'stop_timestamp': 11536592.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 11540637.0,
#    'stop_timestamp': 11540723.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 11543300.0,
#    'stop_timestamp': 11543400.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 11553846.0,
#    'stop_timestamp': 11553950.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11581891.0,
#    'stop_timestamp': 11581943.0,
#    'duration_ms': 53.0,
#    'num_samples': 0},
#   {'start_timestamp': 11583714.0,
#    'stop_timestamp': 11583822.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 11589976.0,
#    'stop_timestamp': 11589977.0,
#    'duration_ms': 2.0,
#    'num_samples': 0},
#   {'start_timestamp': 11593689.0,
#    'stop_timestamp': 11593733.0,
#    'duration_ms': 45.0,
#    'num_samples': 0},
#   {'start_timestamp': 11597711.0,
#    'stop_timestamp': 11597803.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 11599752.0,
#    'stop_timestamp': 11599801.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 11607952.0,
#    'stop_timestamp': 11608054.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11628615.0,
#    'stop_timestamp': 11628693.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 11636665.0,
#    'stop_timestamp': 11636753.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 11646127.0,
#    'stop_timestamp': 11646259.0,
#    'duration_ms': 133.0,
#    'num_samples': 0},
#   {'start_timestamp': 11653800.0,
#    'stop_timestamp': 11653836.0,
#    'duration_ms': 37.0,
#    'num_samples': 0},
#   {'start_timestamp': 11655080.0,
#    'stop_timestamp': 11655165.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 11656754.0,
#    'stop_timestamp': 11656845.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 11659368.0,
#    'stop_timestamp': 11659443.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 11663397.0,
#    'stop_timestamp': 11663532.0,
#    'duration_ms': 136.0,
#    'num_samples': 0},
#   {'start_timestamp': 11666675.0,
#    'stop_timestamp': 11666769.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 11672057.0,
#    'stop_timestamp': 11672124.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 11674487.0,
#    'stop_timestamp': 11674591.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11675811.0,
#    'stop_timestamp': 11675885.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 11683452.0,
#    'stop_timestamp': 11683567.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 11691849.0,
#    'stop_timestamp': 11691928.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 11697521.0,
#    'stop_timestamp': 11697614.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11699111.0,
#    'stop_timestamp': 11699304.0,
#    'duration_ms': 194.0,
#    'num_samples': 0},
#   {'start_timestamp': 11699743.0,
#    'stop_timestamp': 11699863.0,
#    'duration_ms': 121.0,
#    'num_samples': 0},
#   {'start_timestamp': 11703207.0,
#    'stop_timestamp': 11703303.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 11707780.0,
#    'stop_timestamp': 11707870.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 11713357.0,
#    'stop_timestamp': 11713450.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 11716696.0,
#    'stop_timestamp': 11716774.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 11724846.0,
#    'stop_timestamp': 11724945.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11730484.0,
#    'stop_timestamp': 11730561.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 11733949.0,
#    'stop_timestamp': 11734046.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 11739044.0,
#    'stop_timestamp': 11739162.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 11752201.0,
#    'stop_timestamp': 11752266.0,
#    'duration_ms': 66.0,
#    'num_samples': 0},
#   {'start_timestamp': 11762024.0,
#    'stop_timestamp': 11762124.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 11767394.0,
#    'stop_timestamp': 11767458.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 11770140.0,
#    'stop_timestamp': 11770239.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 11781039.0,
#    'stop_timestamp': 11781142.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 11791713.0,
#    'stop_timestamp': 11791780.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 11794050.0,
#    'stop_timestamp': 11794130.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 11797217.0,
#    'stop_timestamp': 11797285.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 11810129.0,
#    'stop_timestamp': 11810256.0,
#    'duration_ms': 128.0,
#    'num_samples': 0},
#   {'start_timestamp': 11814502.0,
#    'stop_timestamp': 11814554.0,
#    'duration_ms': 53.0,
#    'num_samples': 0},
#   {'start_timestamp': 11881848.0,
#    'stop_timestamp': 11881931.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 11884598.0,
#    'stop_timestamp': 11884656.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 11887878.0,
#    'stop_timestamp': 11887918.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 11894441.0,
#    'stop_timestamp': 11894515.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 11896457.0,
#    'stop_timestamp': 11896544.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 11903984.0,
#    'stop_timestamp': 11904074.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 11910286.0,
#    'stop_timestamp': 11910405.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 11917388.0,
#    'stop_timestamp': 11917531.0,
#    'duration_ms': 144.0,
#    'num_samples': 0},
#   {'start_timestamp': 11952462.0,
#    'stop_timestamp': 11952530.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 11961306.0,
#    'stop_timestamp': 11961408.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 11965687.0,
#    'stop_timestamp': 11965791.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 11972326.0,
#    'stop_timestamp': 11972448.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 11974588.0,
#    'stop_timestamp': 11974643.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 11978368.0,
#    'stop_timestamp': 11978444.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 11981577.0,
#    'stop_timestamp': 11981659.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 11984939.0,
#    'stop_timestamp': 11985011.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 12019475.0,
#    'stop_timestamp': 12019530.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 12035089.0,
#    'stop_timestamp': 12035132.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 12056967.0,
#    'stop_timestamp': 12057053.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 12087496.0,
#    'stop_timestamp': 12087554.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 12102294.0,
#    'stop_timestamp': 12102364.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 12110466.0,
#    'stop_timestamp': 12110524.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 12117675.0,
#    'stop_timestamp': 12117725.0,
#    'duration_ms': 51.0,
#    'num_samples': 0},
#   {'start_timestamp': 12127778.0,
#    'stop_timestamp': 12127831.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 12133665.0,
#    'stop_timestamp': 12133707.0,
#    'duration_ms': 43.0,
#    'num_samples': 0},
#   {'start_timestamp': 12138896.0,
#    'stop_timestamp': 12138975.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 12167731.0,
#    'stop_timestamp': 12167853.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 12173585.0,
#    'stop_timestamp': 12173671.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 12184458.0,
#    'stop_timestamp': 12184549.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 12190120.0,
#    'stop_timestamp': 12190236.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 12205119.0,
#    'stop_timestamp': 12205135.0,
#    'duration_ms': 17.0,
#    'num_samples': 0},
#   {'start_timestamp': 12206951.0,
#    'stop_timestamp': 12207042.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 12213997.0,
#    'stop_timestamp': 12214090.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 12221449.0,
#    'stop_timestamp': 12221547.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 12236049.0,
#    'stop_timestamp': 12236156.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 12250386.0,
#    'stop_timestamp': 12250474.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 12260590.0,
#    'stop_timestamp': 12260668.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 12268179.0,
#    'stop_timestamp': 12268287.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 12277882.0,
#    'stop_timestamp': 12277956.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 12608270.0,
#    'stop_timestamp': 12608270.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 12620496.0,
#    'stop_timestamp': 12620565.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 12653456.0,
#    'stop_timestamp': 12653575.0,
#    'duration_ms': 120.0,
#    'num_samples': 0},
#   {'start_timestamp': 12660769.0,
#    'stop_timestamp': 12660769.0,
#    'duration_ms': 1.0,
#    'num_samples': 0},
#   {'start_timestamp': 12666836.0,
#    'stop_timestamp': 12666852.0,
#    'duration_ms': 17.0,
#    'num_samples': 0},
#   {'start_timestamp': 12681522.0,
#    'stop_timestamp': 12681602.0,
#    'duration_ms': 81.0,
#    'num_samples': 0},
#   {'start_timestamp': 12697949.0,
#    'stop_timestamp': 12698039.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 12700267.0,
#    'stop_timestamp': 12700332.0,
#    'duration_ms': 66.0,
#    'num_samples': 0},
#   {'start_timestamp': 12703038.0,
#    'stop_timestamp': 12703125.0,
#    'duration_ms': 88.0,
# ...
#   {'start_timestamp': 13670003.0,
#    'stop_timestamp': 13670084.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 13674773.0,
#    'stop_timestamp': 13674893.0,
#    'duration_ms': 121.0,
#    'num_samples': 0},
#   {'start_timestamp': 13680320.0,
#    'stop_timestamp': 13680387.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 13689148.0,
#    'stop_timestamp': 13689171.0,
#    'duration_ms': 24.0,
#    'num_samples': 0},
#   {'start_timestamp': 13697204.0,
#    'stop_timestamp': 13697257.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 13699885.0,
#    'stop_timestamp': 13699948.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 13705002.0,
#    'stop_timestamp': 13705093.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 13713105.0,
#    'stop_timestamp': 13713158.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 13718797.0,
#    'stop_timestamp': 13718893.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 13720230.0,
#    'stop_timestamp': 13720333.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 13727484.0,
#    'stop_timestamp': 13727611.0,
#    'duration_ms': 128.0,
#    'num_samples': 0},
#   {'start_timestamp': 13729521.0,
#    'stop_timestamp': 13729654.0,
#    'duration_ms': 134.0,
#    'num_samples': 0},
#   {'start_timestamp': 13743709.0,
#    'stop_timestamp': 13743830.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 13750673.0,
#    'stop_timestamp': 13750787.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 13755840.0,
#    'stop_timestamp': 13755995.0,
#    'duration_ms': 156.0,
#    'num_samples': 0},
#   {'start_timestamp': 13775857.0,
#    'stop_timestamp': 13775886.0,
#    'duration_ms': 30.0,
#    'num_samples': 0},
#   {'start_timestamp': 13783524.0,
#    'stop_timestamp': 13783553.0,
#    'duration_ms': 30.0,
#    'num_samples': 0},
#   {'start_timestamp': 13786154.0,
#    'stop_timestamp': 13786195.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 13794882.0,
#    'stop_timestamp': 13794986.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 13798928.0,
#    'stop_timestamp': 13798997.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 13810767.0,
#    'stop_timestamp': 13810831.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 13816654.0,
#    'stop_timestamp': 13816790.0,
#    'duration_ms': 137.0,
#    'num_samples': 0},
#   {'start_timestamp': 13817627.0,
#    'stop_timestamp': 13818168.0,
#    'duration_ms': 542.0,
#    'num_samples': 0},
#   {'start_timestamp': 13832570.0,
#    'stop_timestamp': 13832640.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 13841148.0,
#    'stop_timestamp': 13841258.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 13847642.0,
#    'stop_timestamp': 13847704.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 13868703.0,
#    'stop_timestamp': 13868801.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 13877254.0,
#    'stop_timestamp': 13877344.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 13878578.0,
#    'stop_timestamp': 13878657.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 13881619.0,
#    'stop_timestamp': 13881736.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 13884714.0,
#    'stop_timestamp': 13884832.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 13885375.0,
#    'stop_timestamp': 13885563.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 13886279.0,
#    'stop_timestamp': 13886393.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 13888411.0,
#    'stop_timestamp': 13888528.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 13889622.0,
#    'stop_timestamp': 13889735.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 13895726.0,
#    'stop_timestamp': 13895823.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 13897674.0,
#    'stop_timestamp': 13897771.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 13902810.0,
#    'stop_timestamp': 13902893.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 13905235.0,
#    'stop_timestamp': 13905282.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 13909213.0,
#    'stop_timestamp': 13909294.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 13917603.0,
#    'stop_timestamp': 13917659.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 13920867.0,
#    'stop_timestamp': 13920943.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 13924411.0,
#    'stop_timestamp': 13924481.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 13928617.0,
#    'stop_timestamp': 13928701.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 13942466.0,
#    'stop_timestamp': 13942512.0,
#    'duration_ms': 47.0,
#    'num_samples': 0},
#   {'start_timestamp': 13943433.0,
#    'stop_timestamp': 13943528.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 13957111.0,
#    'stop_timestamp': 13957232.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 13959301.0,
#    'stop_timestamp': 13959397.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 13962637.0,
#    'stop_timestamp': 13962739.0,
#    'duration_ms': 103.0,
#    'num_samples': 0},
#   {'start_timestamp': 13966630.0,
#    'stop_timestamp': 13966780.0,
#    'duration_ms': 151.0,
#    'num_samples': 0},
#   {'start_timestamp': 13969500.0,
#    'stop_timestamp': 13969601.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 13973459.0,
#    'stop_timestamp': 13973547.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 13999147.0,
#    'stop_timestamp': 13999200.0,
#    'duration_ms': 54.0,
#    'num_samples': 0},
#   {'start_timestamp': 14001221.0,
#    'stop_timestamp': 14001243.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 14010561.0,
#    'stop_timestamp': 14010600.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 14015349.0,
#    'stop_timestamp': 14015463.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 14039422.0,
#    'stop_timestamp': 14039518.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 14044016.0,
#    'stop_timestamp': 14044108.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 14063282.0,
#    'stop_timestamp': 14063351.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 14066101.0,
#    'stop_timestamp': 14066144.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 14073385.0,
#    'stop_timestamp': 14073473.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 14074600.0,
#    'stop_timestamp': 14074676.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 14076820.0,
#    'stop_timestamp': 14077025.0,
#    'duration_ms': 206.0,
#    'num_samples': 0},
#   {'start_timestamp': 14077883.0,
#    'stop_timestamp': 14078017.0,
#    'duration_ms': 135.0,
#    'num_samples': 0},
#   {'start_timestamp': 14080316.0,
#    'stop_timestamp': 14080415.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 14091871.0,
#    'stop_timestamp': 14091992.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 14092742.0,
#    'stop_timestamp': 14093233.0,
#    'duration_ms': 492.0,
#    'num_samples': 0},
#   {'start_timestamp': 14096242.0,
#    'stop_timestamp': 14096309.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 14098971.0,
#    'stop_timestamp': 14099032.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 14106052.0,
#    'stop_timestamp': 14106130.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 14106644.0,
#    'stop_timestamp': 14106832.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 14110822.0,
#    'stop_timestamp': 14110967.0,
#    'duration_ms': 146.0,
#    'num_samples': 0},
#   {'start_timestamp': 14121700.0,
#    'stop_timestamp': 14121762.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 14141312.0,
#    'stop_timestamp': 14141413.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 14146565.0,
#    'stop_timestamp': 14146668.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 14147755.0,
#    'stop_timestamp': 14147795.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 14156661.0,
#    'stop_timestamp': 14156767.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 14160084.0,
#    'stop_timestamp': 14160198.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 14170429.0,
#    'stop_timestamp': 14170555.0,
#    'duration_ms': 127.0,
#    'num_samples': 0},
#   {'start_timestamp': 14231754.0,
#    'stop_timestamp': 14231777.0,
#    'duration_ms': 24.0,
#    'num_samples': 0},
#   {'start_timestamp': 14233837.0,
#    'stop_timestamp': 14233886.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 14242622.0,
#    'stop_timestamp': 14242636.0,
#    'duration_ms': 15.0,
#    'num_samples': 0},
#   {'start_timestamp': 14294597.0,
#    'stop_timestamp': 14294750.0,
#    'duration_ms': 154.0,
#    'num_samples': 0},
#   {'start_timestamp': 14297645.0,
#    'stop_timestamp': 14297752.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 14308354.0,
#    'stop_timestamp': 14308432.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 14314380.0,
#    'stop_timestamp': 14314457.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 14322324.0,
#    'stop_timestamp': 14322346.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 14329214.0,
#    'stop_timestamp': 14329298.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 14331445.0,
#    'stop_timestamp': 14331501.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 14336037.0,
#    'stop_timestamp': 14336114.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 14351761.0,
#    'stop_timestamp': 14351910.0,
#    'duration_ms': 150.0,
#    'num_samples': 0},
#   {'start_timestamp': 14352597.0,
#    'stop_timestamp': 14352845.0,
#    'duration_ms': 249.0,
#    'num_samples': 0},
#   {'start_timestamp': 14360063.0,
#    'stop_timestamp': 14360162.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 14361894.0,
#    'stop_timestamp': 14361970.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 14364070.0,
#    'stop_timestamp': 14364113.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 14371322.0,
#    'stop_timestamp': 14371411.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 14392267.0,
#    'stop_timestamp': 14392362.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 14415509.0,
#    'stop_timestamp': 14415602.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 14488993.0,
#    'stop_timestamp': 14489061.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 14512999.0,
#    'stop_timestamp': 14513055.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 14515836.0,
#    'stop_timestamp': 14515939.0,
#    'duration_ms': 104.0,
#    'num_samples': 0},
#   {'start_timestamp': 14532898.0,
#    'stop_timestamp': 14532965.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 14543917.0,
#    'stop_timestamp': 14544004.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 14579267.0,
#    'stop_timestamp': 14579333.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 14582083.0,
#    'stop_timestamp': 14582134.0,
#    'duration_ms': 52.0,
#    'num_samples': 0},
#   {'start_timestamp': 14588729.0,
#    'stop_timestamp': 14588816.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 14594002.0,
#    'stop_timestamp': 14594097.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 14598187.0,
#    'stop_timestamp': 14598253.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 14607065.0,
#    'stop_timestamp': 14607214.0,
#    'duration_ms': 150.0,
#    'num_samples': 0},
#   {'start_timestamp': 14620432.0,
#    'stop_timestamp': 14620508.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 14627313.0,
#    'stop_timestamp': 14627373.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 14655536.0,
#    'stop_timestamp': 14655624.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 14665776.0,
#    'stop_timestamp': 14665837.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 14667812.0,
#    'stop_timestamp': 14667902.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 14671400.0,
#    'stop_timestamp': 14671456.0,
#    'duration_ms': 57.0,
#    'num_samples': 0},
#   {'start_timestamp': 14686795.0,
#    'stop_timestamp': 14686877.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 14690322.0,
#    'stop_timestamp': 14690359.0,
#    'duration_ms': 38.0,
#    'num_samples': 0},
#   {'start_timestamp': 14702028.0,
#    'stop_timestamp': 14702162.0,
#    'duration_ms': 135.0,
#    'num_samples': 0},
#   {'start_timestamp': 14711132.0,
#    'stop_timestamp': 14711284.0,
#    'duration_ms': 153.0,
#    'num_samples': 0},
#   {'start_timestamp': 14712402.0,
#    'stop_timestamp': 14712498.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 14718910.0,
#    'stop_timestamp': 14719072.0,
#    'duration_ms': 163.0,
#    'num_samples': 0},
#   {'start_timestamp': 14725371.0,
#    'stop_timestamp': 14725443.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 14741894.0,
#    'stop_timestamp': 14741990.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 14746803.0,
#    'stop_timestamp': 14746886.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 14750167.0,
#    'stop_timestamp': 14750275.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 14766660.0,
#    'stop_timestamp': 14766733.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 14779104.0,
#    'stop_timestamp': 14779136.0,
#    'duration_ms': 33.0,
#    'num_samples': 0},
#   {'start_timestamp': 14783027.0,
#    'stop_timestamp': 14783104.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 14784623.0,
#    'stop_timestamp': 14784662.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 14788680.0,
#    'stop_timestamp': 14788801.0,
#    'duration_ms': 122.0,
#    'num_samples': 0},
#   {'start_timestamp': 14791098.0,
#    'stop_timestamp': 14791216.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 14794885.0,
#    'stop_timestamp': 14794907.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 14800068.0,
#    'stop_timestamp': 14800137.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 14805258.0,
#    'stop_timestamp': 14805396.0,
#    'duration_ms': 139.0,
#    'num_samples': 0},
#   {'start_timestamp': 14806357.0,
#    'stop_timestamp': 14806550.0,
#    'duration_ms': 194.0,
#    'num_samples': 0},
#   {'start_timestamp': 14812291.0,
#    'stop_timestamp': 14812369.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 14816159.0,
#    'stop_timestamp': 14816251.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 14825929.0,
#    'stop_timestamp': 14825983.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 14829694.0,
#    'stop_timestamp': 14829810.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 14840094.0,
#    'stop_timestamp': 14840179.0,
#    'duration_ms': 86.0,
#    'num_samples': 0}],
#  'data_loss_ratio': 4.762376463954525e-07,
#  'data_loss_ratio_blinks': 0.0,
#  'total_recording_duration_ms': 4199584.0}

# %%
def check_validations(gaze, messages):
    
    for validation in gaze._metadata["validations"]:
        if validation["error"] == "GOOD ERROR":
            continue
        else:
            print(validation["error"], validation["timestamp"])
            bad_val_timestamp = float(validation["timestamp"])     
            found_val = False
          
        for cal in gaze._metadata["calibrations"]:
            cal_timestamp = float(cal["timestamp"])
            if cal_timestamp > bad_val_timestamp and cal_timestamp < bad_val_timestamp + 120000:
                print(f"Calibration after bad validation: {cal}")
                index_bad_val = gaze._metadata["validations"].index(validation)
                next_validation = gaze._metadata['validations'][index_bad_val+1]
                time_between = round((float(next_validation["timestamp"]) - bad_val_timestamp)/60000, 3)
                print(f"next validation: {next_validation}, {time_between} minutes")
                found_val = True
        if not found_val:
            print("No calibration after bad validation")
          
                    
            
                
check_validations(gaze, messages)
# Out:
# FAIR ERROR 9299961.0
# No calibration after bad validation

# %%
gaze._metadata
# Out:
# {'weekday': 'Fri',
#  'month': 'Jan',
#  'day': 17,
#  'time': '08:38:11',
#  'year': 2025,
#  'version_1': 'EYELINK II 1',
#  'version_2': 'EYELINK II CL v5.12 May 12 2017',
#  'resolution': (1585, 1199),
#  'tracking_mode': 'CR',
#  'sampling_rate': 1000.0,
#  'file_sample_filter': '2',
#  'link_sample_filter': '1',
#  'tracked_eye': 'R',
#  'mount_configuration': {'mount_type': 'Desktop',
#   'head_stabilization': 'stabilized',
#   'eyes_recorded': 'monocular',
#   'short_name': 'MTABLER'},
#  'pupil_data_type': 'AREA',
#  'version_number': '5.12',
#  'model': 'EyeLink 1000 Plus',
#  'datetime': datetime.datetime(2025, 1, 17, 8, 38, 11),
#  'calibrations': [{'timestamp': '643197.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '749866.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '875278.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '1149430.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '1874327.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '2293611.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '2344621.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '2770174.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '3292525.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '3843260.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'},
#   {'timestamp': '4534569.0',
#    'num_points': '9',
#    'type': 'P-CR',
#    'tracked_eye': 'RIGHT'}],
#  'validations': [{'timestamp': '771836.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.27',
#    'validation_score_max': '0.59'},
#   {'timestamp': '896235.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.24',
#    'validation_score_max': '0.53'},
#   {'timestamp': '1135329.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.22',
#    'validation_score_max': '0.67'},
#   {'timestamp': '1163698.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.20',
#    'validation_score_max': '0.58'},
#   {'timestamp': '1404262.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.25',
#    'validation_score_max': '0.43'},
#   {'timestamp': '1857881.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.45',
#    'validation_score_max': '0.61'},
#   {'timestamp': '1888578.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.19',
#    'validation_score_max': '0.44'},
#   {'timestamp': '2310454.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.14',
#    'validation_score_max': '0.49'},
#   {'timestamp': '2329443.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.16',
#    'validation_score_max': '0.49'},
#   {'timestamp': '2360274.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.19',
#    'validation_score_max': '0.27'},
#   {'timestamp': '2755300.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.32',
#    'validation_score_max': '0.44'},
#   {'timestamp': '2784764.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.17',
#    'validation_score_max': '0.46'},
#   {'timestamp': '3308267.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.23',
#    'validation_score_max': '0.32'},
#   {'timestamp': '3493952.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.21',
#    'validation_score_max': '0.56'},
#   {'timestamp': '3871154.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.17',
#    'validation_score_max': '0.30'},
#   {'timestamp': '4143930.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.30',
#    'validation_score_max': '0.68'},
#   {'timestamp': '4555488.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.16',
#    'validation_score_max': '0.42'},
#   {'timestamp': '4797206.0',
#    'num_points': '9',
#    'tracked_eye': 'RIGHT',
#    'error': 'GOOD ERROR',
#    'validation_score_avg': '0.17',
#    'validation_score_max': '0.44'}],
#  'blinks': [{'start_timestamp': 955685.0,
#    'stop_timestamp': 955749.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 964549.0,
#    'stop_timestamp': 964655.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 975927.0,
#    'stop_timestamp': 976033.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 982417.0,
#    'stop_timestamp': 982493.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 1007344.0,
#    'stop_timestamp': 1007370.0,
#    'duration_ms': 27.0,
#    'num_samples': 0},
#   {'start_timestamp': 1007501.0,
#    'stop_timestamp': 1007575.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 1009058.0,
#    'stop_timestamp': 1009149.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 1015015.0,
#    'stop_timestamp': 1015064.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 1016109.0,
#    'stop_timestamp': 1016188.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 1027216.0,
#    'stop_timestamp': 1027263.0,
#    'duration_ms': 48.0,
#    'num_samples': 0},
#   {'start_timestamp': 1030469.0,
#    'stop_timestamp': 1030539.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 1035059.0,
#    'stop_timestamp': 1035132.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 1039974.0,
#    'stop_timestamp': 1040063.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 1041620.0,
#    'stop_timestamp': 1041665.0,
#    'duration_ms': 46.0,
#    'num_samples': 0},
#   {'start_timestamp': 1087957.0,
#    'stop_timestamp': 1088025.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 1094749.0,
#    'stop_timestamp': 1094825.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 1095619.0,
#    'stop_timestamp': 1095719.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 1188596.0,
#    'stop_timestamp': 1188714.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 1189605.0,
#    'stop_timestamp': 1189692.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 1191317.0,
#    'stop_timestamp': 1191402.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 1215194.0,
#    'stop_timestamp': 1215278.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 1237010.0,
#    'stop_timestamp': 1237086.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 1258797.0,
#    'stop_timestamp': 1258843.0,
#    'duration_ms': 47.0,
#    'num_samples': 0},
#   {'start_timestamp': 1273209.0,
#    'stop_timestamp': 1273302.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 1300585.0,
#    'stop_timestamp': 1300701.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 1309861.0,
#    'stop_timestamp': 1309940.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 1323416.0,
#    'stop_timestamp': 1323516.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 1324293.0,
#    'stop_timestamp': 1324366.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 1327549.0,
#    'stop_timestamp': 1327624.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 1335716.0,
#    'stop_timestamp': 1335777.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 1344814.0,
#    'stop_timestamp': 1344851.0,
#    'duration_ms': 38.0,
#    'num_samples': 0},
#   {'start_timestamp': 1344983.0,
#    'stop_timestamp': 1345056.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 1360186.0,
#    'stop_timestamp': 1360272.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 1368541.0,
#    'stop_timestamp': 1368608.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 1424059.0,
#    'stop_timestamp': 1424174.0,
#    'duration_ms': 116.0,
#    'num_samples': 0},
#   {'start_timestamp': 1443665.0,
#    'stop_timestamp': 1443742.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 1446539.0,
#    'stop_timestamp': 1446589.0,
#    'duration_ms': 51.0,
#    'num_samples': 0},
#   {'start_timestamp': 1464296.0,
#    'stop_timestamp': 1464369.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 1472856.0,
#    'stop_timestamp': 1472928.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 1486537.0,
#    'stop_timestamp': 1486575.0,
#    'duration_ms': 39.0,
#    'num_samples': 0},
#   {'start_timestamp': 1498098.0,
#    'stop_timestamp': 1498236.0,
#    'duration_ms': 139.0,
#    'num_samples': 0},
#   {'start_timestamp': 1512255.0,
#    'stop_timestamp': 1512363.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 1522262.0,
#    'stop_timestamp': 1522379.0,
#    'duration_ms': 118.0,
#    'num_samples': 0},
#   {'start_timestamp': 1533935.0,
#    'stop_timestamp': 1534016.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 1542828.0,
#    'stop_timestamp': 1542872.0,
#    'duration_ms': 45.0,
#    'num_samples': 0},
#   {'start_timestamp': 1543179.0,
#    'stop_timestamp': 1543252.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 1549201.0,
#    'stop_timestamp': 1549292.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 1555759.0,
#    'stop_timestamp': 1555892.0,
#    'duration_ms': 134.0,
#    'num_samples': 0},
#   {'start_timestamp': 1565307.0,
#    'stop_timestamp': 1565384.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 1579590.0,
#    'stop_timestamp': 1579725.0,
#    'duration_ms': 136.0,
#    'num_samples': 0},
#   {'start_timestamp': 1587812.0,
#    'stop_timestamp': 1587935.0,
#    'duration_ms': 124.0,
#    'num_samples': 0},
#   {'start_timestamp': 1597157.0,
#    'stop_timestamp': 1597281.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 1604663.0,
#    'stop_timestamp': 1604749.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 1624430.0,
#    'stop_timestamp': 1624524.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 1629573.0,
#    'stop_timestamp': 1629640.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 1652273.0,
#    'stop_timestamp': 1652317.0,
#    'duration_ms': 45.0,
#    'num_samples': 0},
#   {'start_timestamp': 1666587.0,
#    'stop_timestamp': 1666686.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 1684503.0,
#    'stop_timestamp': 1684587.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 1712620.0,
#    'stop_timestamp': 1712678.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 1712928.0,
#    'stop_timestamp': 1713069.0,
#    'duration_ms': 142.0,
#    'num_samples': 0},
#   {'start_timestamp': 1735031.0,
#    'stop_timestamp': 1735046.0,
#    'duration_ms': 16.0,
#    'num_samples': 0},
#   {'start_timestamp': 1735505.0,
#    'stop_timestamp': 1735599.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 1743691.0,
#    'stop_timestamp': 1743734.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 1748692.0,
#    'stop_timestamp': 1748792.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 1759994.0,
#    'stop_timestamp': 1760052.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 1760836.0,
#    'stop_timestamp': 1760903.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 1772806.0,
#    'stop_timestamp': 1772865.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 1776111.0,
#    'stop_timestamp': 1776140.0,
#    'duration_ms': 30.0,
#    'num_samples': 0},
#   {'start_timestamp': 1776328.0,
#    'stop_timestamp': 1776438.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 1781227.0,
#    'stop_timestamp': 1781314.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 1783431.0,
#    'stop_timestamp': 1783474.0,
#    'duration_ms': 44.0,
#    'num_samples': 0},
#   {'start_timestamp': 1798506.0,
#    'stop_timestamp': 1798596.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 1804016.0,
#    'stop_timestamp': 1804113.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 1807322.0,
#    'stop_timestamp': 1807416.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 1813924.0,
#    'stop_timestamp': 1814001.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 1815598.0,
#    'stop_timestamp': 1815619.0,
#    'duration_ms': 22.0,
#    'num_samples': 0},
#   {'start_timestamp': 1815755.0,
#    'stop_timestamp': 1815810.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 1834477.0,
#    'stop_timestamp': 1834574.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 1895396.0,
#    'stop_timestamp': 1895496.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 1898425.0,
#    'stop_timestamp': 1898507.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 1909745.0,
#    'stop_timestamp': 1909793.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 1922450.0,
#    'stop_timestamp': 1922601.0,
#    'duration_ms': 152.0,
#    'num_samples': 0},
#   {'start_timestamp': 1924380.0,
#    'stop_timestamp': 1924489.0,
#    'duration_ms': 110.0,
#    'num_samples': 0},
#   {'start_timestamp': 1926738.0,
#    'stop_timestamp': 1926805.0,
#    'duration_ms': 68.0,
#    'num_samples': 0},
#   {'start_timestamp': 1930727.0,
#    'stop_timestamp': 1930790.0,
#    'duration_ms': 64.0,
#    'num_samples': 0},
#   {'start_timestamp': 1947028.0,
#    'stop_timestamp': 1947122.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 1952463.0,
#    'stop_timestamp': 1952514.0,
#    'duration_ms': 52.0,
#    'num_samples': 0},
#   {'start_timestamp': 1953277.0,
#    'stop_timestamp': 1953366.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 1961215.0,
#    'stop_timestamp': 1961289.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 1971377.0,
#    'stop_timestamp': 1971475.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 1996545.0,
#    'stop_timestamp': 1996676.0,
#    'duration_ms': 132.0,
#    'num_samples': 0},
#   {'start_timestamp': 1998782.0,
#    'stop_timestamp': 1998930.0,
#    'duration_ms': 149.0,
#    'num_samples': 0},
#   {'start_timestamp': 2008866.0,
#    'stop_timestamp': 2008988.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 2010615.0,
#    'stop_timestamp': 2010709.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 2021211.0,
#    'stop_timestamp': 2021346.0,
#    'duration_ms': 136.0,
#    'num_samples': 0},
#   {'start_timestamp': 2030619.0,
#    'stop_timestamp': 2030707.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 2048147.0,
#    'stop_timestamp': 2048204.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 2048496.0,
#    'stop_timestamp': 2048755.0,
#    'duration_ms': 260.0,
#    'num_samples': 0},
#   {'start_timestamp': 2066022.0,
#    'stop_timestamp': 2066151.0,
#    'duration_ms': 130.0,
#    'num_samples': 0},
#   {'start_timestamp': 2076225.0,
#    'stop_timestamp': 2076581.0,
#    'duration_ms': 357.0,
#    'num_samples': 0},
#   {'start_timestamp': 2086711.0,
#    'stop_timestamp': 2086818.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 2087041.0,
#    'stop_timestamp': 2087172.0,
#    'duration_ms': 132.0,
#    'num_samples': 0},
#   {'start_timestamp': 2107635.0,
#    'stop_timestamp': 2107693.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 2110987.0,
#    'stop_timestamp': 2111101.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 2130801.0,
#    'stop_timestamp': 2130830.0,
#    'duration_ms': 30.0,
#    'num_samples': 0},
#   {'start_timestamp': 2140356.0,
#    'stop_timestamp': 2140426.0,
#    'duration_ms': 71.0,
#    'num_samples': 0},
#   {'start_timestamp': 2141997.0,
#    'stop_timestamp': 2142095.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 2160229.0,
#    'stop_timestamp': 2160286.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 2163534.0,
#    'stop_timestamp': 2163621.0,
#    'duration_ms': 88.0,
#    'num_samples': 0},
#   {'start_timestamp': 2398022.0,
#    'stop_timestamp': 2400514.0,
#    'duration_ms': 2493.0,
#    'num_samples': 0},
#   {'start_timestamp': 2430144.0,
#    'stop_timestamp': 2430215.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 2476877.0,
#    'stop_timestamp': 2476985.0,
#    'duration_ms': 109.0,
#    'num_samples': 0},
#   {'start_timestamp': 2490098.0,
#    'stop_timestamp': 2490189.0,
#    'duration_ms': 92.0,
#    'num_samples': 0},
#   {'start_timestamp': 2503610.0,
#    'stop_timestamp': 2503744.0,
#    'duration_ms': 135.0,
#    'num_samples': 0},
#   {'start_timestamp': 2520468.0,
#    'stop_timestamp': 2520620.0,
#    'duration_ms': 153.0,
#    'num_samples': 0},
#   {'start_timestamp': 2522281.0,
#    'stop_timestamp': 2522409.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 2560795.0,
#    'stop_timestamp': 2560831.0,
#    'duration_ms': 37.0,
#    'num_samples': 0},
#   {'start_timestamp': 2569647.0,
#    'stop_timestamp': 2569705.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 2569846.0,
#    'stop_timestamp': 2569988.0,
#    'duration_ms': 143.0,
#    'num_samples': 0},
#   {'start_timestamp': 2579568.0,
#    'stop_timestamp': 2579641.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 2591634.0,
#    'stop_timestamp': 2591758.0,
#    'duration_ms': 125.0,
#    'num_samples': 0},
#   {'start_timestamp': 2598842.0,
#    'stop_timestamp': 2599030.0,
#    'duration_ms': 189.0,
#    'num_samples': 0},
#   {'start_timestamp': 2599884.0,
#    'stop_timestamp': 2600045.0,
#    'duration_ms': 162.0,
#    'num_samples': 0},
#   {'start_timestamp': 2607719.0,
#    'stop_timestamp': 2607724.0,
#    'duration_ms': 6.0,
#    'num_samples': 0},
#   {'start_timestamp': 2621942.0,
#    'stop_timestamp': 2622194.0,
#    'duration_ms': 253.0,
#    'num_samples': 0},
#   {'start_timestamp': 2636973.0,
#    'stop_timestamp': 2637059.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 2638227.0,
#    'stop_timestamp': 2638293.0,
#    'duration_ms': 67.0,
#    'num_samples': 0},
#   {'start_timestamp': 2671519.0,
#    'stop_timestamp': 2671588.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 2676403.0,
#    'stop_timestamp': 2676496.0,
#    'duration_ms': 94.0,
#    'num_samples': 0},
#   {'start_timestamp': 2679827.0,
#    'stop_timestamp': 2679957.0,
#    'duration_ms': 131.0,
#    'num_samples': 0},
#   {'start_timestamp': 2707317.0,
#    'stop_timestamp': 2707431.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 2718543.0,
#    'stop_timestamp': 2718605.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 2722959.0,
#    'stop_timestamp': 2723044.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 2811529.0,
#    'stop_timestamp': 2811634.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 2832199.0,
#    'stop_timestamp': 2832329.0,
#    'duration_ms': 131.0,
#    'num_samples': 0},
#   {'start_timestamp': 2843434.0,
#    'stop_timestamp': 2843581.0,
#    'duration_ms': 148.0,
#    'num_samples': 0},
#   {'start_timestamp': 2856255.0,
#    'stop_timestamp': 2856399.0,
#    'duration_ms': 145.0,
#    'num_samples': 0},
#   {'start_timestamp': 2862226.0,
#    'stop_timestamp': 2862304.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 2862432.0,
#    'stop_timestamp': 2862529.0,
#    'duration_ms': 98.0,
#    'num_samples': 0},
#   {'start_timestamp': 2878311.0,
#    'stop_timestamp': 2878444.0,
#    'duration_ms': 134.0,
#    'num_samples': 0},
#   {'start_timestamp': 2914361.0,
#    'stop_timestamp': 2914509.0,
#    'duration_ms': 149.0,
#    'num_samples': 0},
#   {'start_timestamp': 2943182.0,
#    'stop_timestamp': 2943257.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 2959213.0,
#    'stop_timestamp': 2959284.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 2982009.0,
#    'stop_timestamp': 2982098.0,
#    'duration_ms': 90.0,
#    'num_samples': 0},
#   {'start_timestamp': 2987755.0,
#    'stop_timestamp': 2987883.0,
#    'duration_ms': 129.0,
#    'num_samples': 0},
#   {'start_timestamp': 3004647.0,
#    'stop_timestamp': 3004731.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 3004980.0,
#    'stop_timestamp': 3005249.0,
#    'duration_ms': 270.0,
#    'num_samples': 0},
#   {'start_timestamp': 3008561.0,
#    'stop_timestamp': 3008629.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 3010100.0,
#    'stop_timestamp': 3010173.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 3023250.0,
#    'stop_timestamp': 3023360.0,
#    'duration_ms': 111.0,
#    'num_samples': 0},
#   {'start_timestamp': 3028224.0,
#    'stop_timestamp': 3028394.0,
#    'duration_ms': 171.0,
#    'num_samples': 0},
#   {'start_timestamp': 3037840.0,
#    'stop_timestamp': 3037908.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 3051155.0,
#    'stop_timestamp': 3051209.0,
#    'duration_ms': 55.0,
#    'num_samples': 0},
#   {'start_timestamp': 3063316.0,
#    'stop_timestamp': 3063388.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 3066773.0,
#    'stop_timestamp': 3066880.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 3082655.0,
#    'stop_timestamp': 3082703.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 3347197.0,
#    'stop_timestamp': 3347353.0,
#    'duration_ms': 157.0,
#    'num_samples': 0},
#   {'start_timestamp': 3369546.0,
#    'stop_timestamp': 3369672.0,
#    'duration_ms': 127.0,
#    'num_samples': 0},
#   {'start_timestamp': 3425275.0,
#    'stop_timestamp': 3425316.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 3427426.0,
#    'stop_timestamp': 3427542.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 3443860.0,
#    'stop_timestamp': 3444000.0,
#    'duration_ms': 141.0,
#    'num_samples': 0},
#   {'start_timestamp': 3473023.0,
#    'stop_timestamp': 3473180.0,
#    'duration_ms': 158.0,
#    'num_samples': 0},
#   {'start_timestamp': 3517082.0,
#    'stop_timestamp': 3517228.0,
#    'duration_ms': 147.0,
#    'num_samples': 0},
#   {'start_timestamp': 3538256.0,
#    'stop_timestamp': 3538374.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 3557542.0,
#    'stop_timestamp': 3557636.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 3596204.0,
#    'stop_timestamp': 3596272.0,
#    'duration_ms': 69.0,
#    'num_samples': 0},
#   {'start_timestamp': 3611704.0,
#    'stop_timestamp': 3611762.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 3634436.0,
#    'stop_timestamp': 3634549.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 3642554.0,
#    'stop_timestamp': 3642612.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 3658437.0,
#    'stop_timestamp': 3658516.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 3668190.0,
#    'stop_timestamp': 3668313.0,
#    'duration_ms': 124.0,
#    'num_samples': 0},
#   {'start_timestamp': 3678803.0,
#    'stop_timestamp': 3678845.0,
#    'duration_ms': 43.0,
#    'num_samples': 0},
#   {'start_timestamp': 3702295.0,
#    'stop_timestamp': 3702341.0,
#    'duration_ms': 47.0,
#    'num_samples': 0},
#   {'start_timestamp': 3702507.0,
#    'stop_timestamp': 3702647.0,
#    'duration_ms': 141.0,
#    'num_samples': 0},
#   {'start_timestamp': 3722162.0,
#    'stop_timestamp': 3722233.0,
#    'duration_ms': 72.0,
#    'num_samples': 0},
#   {'start_timestamp': 3723830.0,
#    'stop_timestamp': 3723942.0,
#    'duration_ms': 113.0,
#    'num_samples': 0},
#   {'start_timestamp': 3727012.0,
#    'stop_timestamp': 3727156.0,
#    'duration_ms': 145.0,
#    'num_samples': 0},
#   {'start_timestamp': 3728158.0,
#    'stop_timestamp': 3728183.0,
#    'duration_ms': 26.0,
#    'num_samples': 0},
#   {'start_timestamp': 3732061.0,
#    'stop_timestamp': 3732092.0,
#    'duration_ms': 32.0,
#    'num_samples': 0},
#   {'start_timestamp': 3734308.0,
#    'stop_timestamp': 3734413.0,
#    'duration_ms': 106.0,
#    'num_samples': 0},
#   {'start_timestamp': 3764752.0,
#    'stop_timestamp': 3764826.0,
#    'duration_ms': 75.0,
#    'num_samples': 0},
#   {'start_timestamp': 3768749.0,
#    'stop_timestamp': 3768769.0,
#    'duration_ms': 21.0,
#    'num_samples': 0},
#   {'start_timestamp': 3768879.0,
#    'stop_timestamp': 3768974.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 3777093.0,
#    'stop_timestamp': 3777134.0,
#    'duration_ms': 42.0,
#    'num_samples': 0},
#   {'start_timestamp': 3798526.0,
#    'stop_timestamp': 3798627.0,
#    'duration_ms': 102.0,
#    'num_samples': 0},
#   {'start_timestamp': 3803672.0,
#    'stop_timestamp': 3803771.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 3886627.0,
#    'stop_timestamp': 3886639.0,
#    'duration_ms': 13.0,
#    'num_samples': 0},
#   {'start_timestamp': 3886827.0,
#    'stop_timestamp': 3886911.0,
#    'duration_ms': 85.0,
#    'num_samples': 0},
#   {'start_timestamp': 3889727.0,
#    'stop_timestamp': 3889786.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 3914360.0,
#    'stop_timestamp': 3914452.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 3919640.0,
#    'stop_timestamp': 3919702.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 3928604.0,
#    'stop_timestamp': 3928780.0,
#    'duration_ms': 177.0,
#    'num_samples': 0},
#   {'start_timestamp': 3933201.0,
#    'stop_timestamp': 3933289.0,
#    'duration_ms': 89.0,
#    'num_samples': 0},
#   {'start_timestamp': 3935494.0,
#    'stop_timestamp': 3935646.0,
#    'duration_ms': 153.0,
#    'num_samples': 0},
#   {'start_timestamp': 3948362.0,
#    'stop_timestamp': 3948623.0,
#    'duration_ms': 262.0,
#    'num_samples': 0},
#   {'start_timestamp': 3949313.0,
#    'stop_timestamp': 3949370.0,
#    'duration_ms': 58.0,
#    'num_samples': 0},
#   {'start_timestamp': 3959023.0,
#    'stop_timestamp': 3959130.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 3962442.0,
#    'stop_timestamp': 3962568.0,
#    'duration_ms': 127.0,
#    'num_samples': 0},
#   {'start_timestamp': 4015542.0,
#    'stop_timestamp': 4015606.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 4022052.0,
#    'stop_timestamp': 4022135.0,
#    'duration_ms': 84.0,
#    'num_samples': 0},
#   {'start_timestamp': 4024581.0,
#    'stop_timestamp': 4024636.0,
#    'duration_ms': 56.0,
#    'num_samples': 0},
#   {'start_timestamp': 4027069.0,
#    'stop_timestamp': 4027151.0,
#    'duration_ms': 83.0,
#    'num_samples': 0},
#   {'start_timestamp': 4034386.0,
#    'stop_timestamp': 4034419.0,
#    'duration_ms': 34.0,
#    'num_samples': 0},
#   {'start_timestamp': 4036678.0,
#    'stop_timestamp': 4036777.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 4042627.0,
#    'stop_timestamp': 4042706.0,
#    'duration_ms': 80.0,
#    'num_samples': 0},
#   {'start_timestamp': 4050527.0,
#    'stop_timestamp': 4050540.0,
#    'duration_ms': 14.0,
#    'num_samples': 0},
#   {'start_timestamp': 4051689.0,
#    'stop_timestamp': 4051749.0,
#    'duration_ms': 61.0,
#    'num_samples': 0},
#   {'start_timestamp': 4062307.0,
#    'stop_timestamp': 4062401.0,
#    'duration_ms': 95.0,
#    'num_samples': 0},
#   {'start_timestamp': 4065954.0,
#    'stop_timestamp': 4065976.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 4071753.0,
#    'stop_timestamp': 4071866.0,
#    'duration_ms': 114.0,
#    'num_samples': 0},
#   {'start_timestamp': 4080441.0,
#    'stop_timestamp': 4080492.0,
#    'duration_ms': 52.0,
#    'num_samples': 0},
#   {'start_timestamp': 4151908.0,
#    'stop_timestamp': 4152006.0,
#    'duration_ms': 99.0,
#    'num_samples': 0},
#   {'start_timestamp': 4156219.0,
#    'stop_timestamp': 4156269.0,
#    'duration_ms': 51.0,
#    'num_samples': 0},
#   {'start_timestamp': 4159424.0,
#    'stop_timestamp': 4159449.0,
#    'duration_ms': 26.0,
#    'num_samples': 0},
#   {'start_timestamp': 4159616.0,
#    'stop_timestamp': 4159716.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 4160838.0,
#    'stop_timestamp': 4160913.0,
#    'duration_ms': 76.0,
#    'num_samples': 0},
#   {'start_timestamp': 4162865.0,
#    'stop_timestamp': 4162923.0,
#    'duration_ms': 59.0,
#    'num_samples': 0},
#   {'start_timestamp': 4163081.0,
#    'stop_timestamp': 4163176.0,
#    'duration_ms': 96.0,
#    'num_samples': 0},
#   {'start_timestamp': 4168383.0,
#    'stop_timestamp': 4168460.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 4172621.0,
#    'stop_timestamp': 4172746.0,
#    'duration_ms': 126.0,
#    'num_samples': 0},
#   {'start_timestamp': 4177667.0,
#    'stop_timestamp': 4177789.0,
#    'duration_ms': 123.0,
#    'num_samples': 0},
#   {'start_timestamp': 4184002.0,
#    'stop_timestamp': 4184044.0,
#    'duration_ms': 43.0,
#    'num_samples': 0},
#   {'start_timestamp': 4184434.0,
#    'stop_timestamp': 4184578.0,
#    'duration_ms': 145.0,
#    'num_samples': 0},
#   {'start_timestamp': 4194806.0,
#    'stop_timestamp': 4194821.0,
#    'duration_ms': 16.0,
#    'num_samples': 0},
#   {'start_timestamp': 4199164.0,
#    'stop_timestamp': 4199183.0,
#    'duration_ms': 20.0,
#    'num_samples': 0},
#   {'start_timestamp': 4199332.0,
#    'stop_timestamp': 4199404.0,
#    'duration_ms': 73.0,
#    'num_samples': 0},
#   {'start_timestamp': 4203390.0,
#    'stop_timestamp': 4203435.0,
#    'duration_ms': 46.0,
#    'num_samples': 0},
#   {'start_timestamp': 4206712.0,
#    'stop_timestamp': 4206837.0,
#    'duration_ms': 126.0,
#    'num_samples': 0},
#   {'start_timestamp': 4208663.0,
#    'stop_timestamp': 4208725.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 4212179.0,
#    'stop_timestamp': 4212248.0,
#    'duration_ms': 70.0,
#    'num_samples': 0},
#   {'start_timestamp': 4221241.0,
#    'stop_timestamp': 4221341.0,
#    'duration_ms': 101.0,
#    'num_samples': 0},
#   {'start_timestamp': 4227861.0,
#    'stop_timestamp': 4227951.0,
#    'duration_ms': 91.0,
#    'num_samples': 0},
#   {'start_timestamp': 4240139.0,
#    'stop_timestamp': 4240203.0,
#    'duration_ms': 65.0,
#    'num_samples': 0},
#   {'start_timestamp': 4250718.0,
#    'stop_timestamp': 4250852.0,
#    'duration_ms': 135.0,
#    'num_samples': 0},
#   {'start_timestamp': 4256831.0,
#    'stop_timestamp': 4256893.0,
#    'duration_ms': 63.0,
#    'num_samples': 0},
#   {'start_timestamp': 4269815.0,
#    'stop_timestamp': 4269931.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 4278936.0,
#    'stop_timestamp': 4279073.0,
#    'duration_ms': 138.0,
#    'num_samples': 0},
#   {'start_timestamp': 4283565.0,
#    'stop_timestamp': 4283966.0,
#    'duration_ms': 402.0,
#    'num_samples': 0},
#   {'start_timestamp': 4294656.0,
#    'stop_timestamp': 4294772.0,
#    'duration_ms': 117.0,
#    'num_samples': 0},
#   {'start_timestamp': 4319752.0,
#    'stop_timestamp': 4319851.0,
#    'duration_ms': 100.0,
#    'num_samples': 0},
#   {'start_timestamp': 4323090.0,
#    'stop_timestamp': 4323197.0,
#    'duration_ms': 108.0,
#    'num_samples': 0},
#   {'start_timestamp': 4353338.0,
#    'stop_timestamp': 4353358.0,
#    'duration_ms': 21.0,
#    'num_samples': 0},
#   {'start_timestamp': 4361187.0,
#    'stop_timestamp': 4361340.0,
#    'duration_ms': 154.0,
#    'num_samples': 0},
#   {'start_timestamp': 4371131.0,
#    'stop_timestamp': 4371204.0,
#    'duration_ms': 74.0,
#    'num_samples': 0},
#   {'start_timestamp': 4375379.0,
#    'stop_timestamp': 4375457.0,
#    'duration_ms': 79.0,
#    'num_samples': 0},
#   {'start_timestamp': 4392089.0,
#    'stop_timestamp': 4392181.0,
#    'duration_ms': 93.0,
#    'num_samples': 0},
#   {'start_timestamp': 4430727.0,
#    'stop_timestamp': 4430841.0,
#    'duration_ms': 115.0,
#    'num_samples': 0},
#   {'start_timestamp': 4447357.0,
#    'stop_timestamp': 4447406.0,
#    'duration_ms': 50.0,
#    'num_samples': 0},
#   {'start_timestamp': 4458654.0,
#    'stop_timestamp': 4458772.0,
#    'duration_ms': 119.0,
#    'num_samples': 0},
#   {'start_timestamp': 4472626.0,
#    'stop_timestamp': 4472666.0,
#    'duration_ms': 41.0,
#    'num_samples': 0},
#   {'start_timestamp': 4481883.0,
#    'stop_timestamp': 4481911.0,
#    'duration_ms': 29.0,
#    'num_samples': 0},
#   {'start_timestamp': 4493344.0,
#    'stop_timestamp': 4493450.0,
#    'duration_ms': 107.0,
#    'num_samples': 0},
#   {'start_timestamp': 4562263.0,
#    'stop_timestamp': 4562324.0,
#    'duration_ms': 62.0,
#    'num_samples': 0},
#   {'start_timestamp': 4568538.0,
#    'stop_timestamp': 4568597.0,
#    'duration_ms': 60.0,
#    'num_samples': 0},
#   {'start_timestamp': 4569881.0,
#    'stop_timestamp': 4569926.0,
#    'duration_ms': 46.0,
#    'num_samples': 0},
#   {'start_timestamp': 4587070.0,
#    'stop_timestamp': 4587151.0,
#    'duration_ms': 82.0,
#    'num_samples': 0},
#   {'start_timestamp': 4590220.0,
#    'stop_timestamp': 4590316.0,
#    'duration_ms': 97.0,
#    'num_samples': 0},
#   {'start_timestamp': 4597078.0,
#    'stop_timestamp': 4597164.0,
#    'duration_ms': 87.0,
#    'num_samples': 0},
#   {'start_timestamp': 4618284.0,
#    'stop_timestamp': 4618388.0,
#    'duration_ms': 105.0,
#    'num_samples': 0},
#   {'start_timestamp': 4657130.0,
#    'stop_timestamp': 4657162.0,
#    'duration_ms': 33.0,
#    'num_samples': 0},
#   {'start_timestamp': 4680582.0,
#    'stop_timestamp': 4680630.0,
#    'duration_ms': 49.0,
#    'num_samples': 0},
#   {'start_timestamp': 4683791.0,
#    'stop_timestamp': 4683830.0,
#    'duration_ms': 40.0,
#    'num_samples': 0},
#   {'start_timestamp': 4684005.0,
#    'stop_timestamp': 4684132.0,
#    'duration_ms': 128.0,
#    'num_samples': 0},
#   {'start_timestamp': 4687639.0,
#    'stop_timestamp': 4687716.0,
#    'duration_ms': 78.0,
#    'num_samples': 0},
#   {'start_timestamp': 4709345.0,
#    'stop_timestamp': 4709367.0,
#    'duration_ms': 23.0,
#    'num_samples': 0},
#   {'start_timestamp': 4712329.0,
#    'stop_timestamp': 4712405.0,
#    'duration_ms': 77.0,
#    'num_samples': 0},
#   {'start_timestamp': 4723471.0,
#    'stop_timestamp': 4723556.0,
#    'duration_ms': 86.0,
#    'num_samples': 0},
#   {'start_timestamp': 4741156.0,
#    'stop_timestamp': 4741240.0,
#    'duration_ms': 85.0,
#    'num_samples': 0}],
#  'data_loss_ratio': 3.693651499548636e-07,
#  'data_loss_ratio_blinks': 0.0,
#  'total_recording_duration_ms': 2707348.0}
